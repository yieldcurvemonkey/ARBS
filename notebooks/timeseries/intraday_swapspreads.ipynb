# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import nest_asyncio
nest_asyncio.apply()

import datetime
import pytz
NYC_tz = pytz.timezone("America/New_York") 

import warnings
warnings.filterwarnings(
    "ignore",
    category=UserWarning,
)

import sys
sys.path.append("../../")

from RVUtils.plt_timeseries import make_secondary_axis_plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from TB.IRSwapSpreadsTB import IRSwapSpreadsTB

# %%
# tb = IRSwapSpreadsTB(source="SDR-WSJ-INTRADAY-SPREADOVER", curve_name="USD-SOFR-1D", show_tqdm=True)
tb = IRSwapSpreadsTB(source="SDR-USTS_WEBULL_WSJ_LIVE-INTRADAY-SPREADOVER", curve_name="USD-SOFR-1D", show_tqdm=True)

start = NYC_tz.localize(datetime.datetime(2026, 3, 20, 7, 0))
end = NYC_tz.localize(datetime.datetime(2026, 3, 24, 15, 0))

headline = "2Y"
df = tb.get_timeseries(
    start=start,
    end=end,
    tenors=[headline],
    include_components=True,
    smoothing_window=20,
    deadband_threshold=0.33,
    deadband_snap=0.25,
    ignore_cache=False,
)
df
# Out:
# CACHE HIT...: 100%|██████████| 2/2 [00:00<00:00, 22.72it/s]
# MERGING SLICES...: 100%|██████████| 2/2 [00:00<00:00, 65.01it/s]
# FETCHING INTRADAY SDR SLICES...: 100%|██████████| 6/6 [00:00<00:00, 10.48it/s]
# MERGING SLICES...: 100%|██████████| 2/2 [00:00<00:00, 53.96it/s]
# BUILDING 2Y SDR VWAP:   0%|          | 0/3 [00:00<?, ?it/s]
# BUILDING PRICERS FROM CACHE: 100%|██████████| 1683/1683 [00:00<00:00, 548571.16it/s]
# PRICING FIXED-RATE BONDS.: 100%|██████████| 3361/3361 [00:00<00:00, 103024.55it/s]
#                            2Y_SWAP_RATE_PCT  2Y_UST_YIELD_PCT  \
# Date
# 2026-03-20 07:00:00-04:00          3.683733             3.793
# 2026-03-20 07:01:00-04:00          3.683733             3.793
# 2026-03-20 07:02:00-04:00          3.683733             3.793
# 2026-03-20 07:03:00-04:00          3.683733             3.793
# 2026-03-20 07:04:00-04:00          3.683733             3.793
# ...                                     ...               ...
# 2026-03-24 14:56:00-04:00            3.7565             3.925
# 2026-03-24 14:57:00-04:00            3.7565             3.929
# 2026-03-24 14:58:00-04:00            3.7565             3.929
# 2026-03-24 14:59:00-04:00            3.7565             3.931
# 2026-03-24 15:00:00-04:00            3.7565             3.927
#
#                            2Y_SWAP_SPREAD_BPS  2Y_SWAP_SPREAD_BPS_SMA_20  \
# Date
# 2026-03-20 07:00:00-04:00          -10.926667                 -10.926667
# 2026-03-20 07:01:00-04:00          -10.926667                 -10.926667
# 2026-03-20 07:02:00-04:00          -10.926667                 -10.926667
# 2026-03-20 07:03:00-04:00          -10.926667                 -10.926667
# 2026-03-20 07:04:00-04:00          -10.926667                 -10.926667
# ...                                       ...                        ...
# 2026-03-24 14:56:00-04:00              -16.85                 -17.197500
# 2026-03-24 14:57:00-04:00              -17.25                 -17.205000
# 2026-03-24 14:58:00-04:00              -17.25                 -17.207500
# 2026-03-24 14:59:00-04:00              -17.45                 -17.225000
# 2026-03-24 15:00:00-04:00              -17.05                 -17.210000
#
#                            2Y_SWAP_SPREAD_BPS_EMA_20  \
# Date
# 2026-03-20 07:00:00-04:00                 -10.926667
# 2026-03-20 07:01:00-04:00                 -10.926667
# 2026-03-20 07:02:00-04:00                 -10.926667
# 2026-03-20 07:03:00-04:00                 -10.926667
# 2026-03-20 07:04:00-04:00                 -10.926667
# ...                                              ...
# 2026-03-24 14:56:00-04:00                 -17.069259
# 2026-03-24 14:57:00-04:00                 -17.086473
# 2026-03-24 14:58:00-04:00                 -17.102047
# 2026-03-24 14:59:00-04:00                 -17.135185
# 2026-03-24 15:00:00-04:00                 -17.127072
#
#                            2Y_SWAP_SPREAD_BPS_MEDIAN_20  \
# Date
# 2026-03-20 07:00:00-04:00                    -10.926667
# 2026-03-20 07:01:00-04:00                    -10.926667
# 2026-03-20 07:02:00-04:00                    -10.926667
# 2026-03-20 07:03:00-04:00                    -10.926667
# 2026-03-20 07:04:00-04:00                    -10.926667
# ...                                                 ...
# 2026-03-24 14:56:00-04:00                    -17.150000
# 2026-03-24 14:57:00-04:00                    -17.225000
# 2026-03-24 14:58:00-04:00                    -17.250000
# 2026-03-24 14:59:00-04:00                    -17.300000
# 2026-03-24 15:00:00-04:00                    -17.250000
#
#                            2Y_SWAP_SPREAD_BPS_STEP
# Date
# 2026-03-20 07:00:00-04:00               -10.926667
# 2026-03-20 07:01:00-04:00               -10.926667
# 2026-03-20 07:02:00-04:00               -10.926667
# 2026-03-20 07:03:00-04:00               -10.926667
# 2026-03-20 07:04:00-04:00               -10.926667
# ...                                            ...
# 2026-03-24 14:56:00-04:00               -16.750000
# 2026-03-24 14:57:00-04:00               -17.250000
# 2026-03-24 14:58:00-04:00               -17.250000
# 2026-03-24 14:59:00-04:00               -17.250000
# 2026-03-24 15:00:00-04:00               -17.250000
#
# [3361 rows x 7 columns]

# %%
plot, fig, _, _, legend = make_secondary_axis_plot(engine="plotly")
plot(df[f"{headline}_SWAP_SPREAD_BPS_STEP"], which="left")
plot(df[f"{headline}_UST_YIELD_PCT"], which="right")
plot(df[f"{headline}_SWAP_RATE_PCT"], which="right")
legend(valfmt="{:.3f}", show_date=True)
