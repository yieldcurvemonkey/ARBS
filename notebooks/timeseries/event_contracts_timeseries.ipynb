# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import nest_asyncio
nest_asyncio.apply()

import datetime
import pytz
NYC_tz = pytz.timezone("America/New_York") 

import sys
sys.path.append("../../")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from MDP.EventContracts.EventContractsMDP import EventContractsMDP
from Query.EventContracts.EventContractQuery import EventContractQuery
from Query.EventContracts.EventContractValue import EventContractValue
from Query.EventContracts.EventContractStructure import EventContractStructure

from RVUtils.plt_timeseries import make_secondary_axis_plot

# %%
mdp = EventContractsMDP(source="KALSHI")
pricer = mdp.get_pricer({
    "ticker": "FEDHIKE-26DEC31",
    "start": NYC_tz.localize(datetime.datetime(2026, 1, 1, 0, 0)),
    "end": NYC_tz.localize(datetime.datetime(2026, 3, 24, 16, 0)),
    "period_interval": 60,  
})

df = pricer.data.ffill()
df
# Out:
#                            open  high   low  close   mean  previous  volume  \
# timestamp
# 2026-01-01 05:00:00+00:00  0.13  0.13  0.13   0.13  0.130      0.13     0.0
# 2026-01-01 06:00:00+00:00  0.13  0.13  0.13   0.13  0.130      0.13     0.0
# 2026-01-01 07:00:00+00:00  0.13  0.13  0.13   0.13  0.130      0.13     0.0
# 2026-01-01 08:00:00+00:00  0.13  0.13  0.13   0.13  0.130      0.13     0.0
# 2026-01-01 09:00:00+00:00  0.13  0.13  0.13   0.13  0.130      0.13     0.0
# ...                         ...   ...   ...    ...    ...       ...     ...
# 2026-03-24 16:00:00+00:00  0.22  0.22  0.22   0.22  0.220      0.22     0.0
# 2026-03-24 17:00:00+00:00  0.22  0.22  0.22   0.22  0.220      0.22   107.0
# 2026-03-24 18:00:00+00:00  0.22  0.22  0.22   0.22  0.220      0.22     0.0
# 2026-03-24 19:00:00+00:00  0.22  0.22  0.22   0.22  0.220      0.22     0.0
# 2026-03-24 20:00:00+00:00  0.21  0.23  0.21   0.23  0.224      0.22   855.0
#
#                            open_interest
# timestamp
# 2026-01-01 05:00:00+00:00        52710.0
# 2026-01-01 06:00:00+00:00        52710.0
# 2026-01-01 07:00:00+00:00        52710.0
# 2026-01-01 08:00:00+00:00        52710.0
# 2026-01-01 09:00:00+00:00        52710.0
# ...                                  ...
# 2026-03-24 16:00:00+00:00       100611.0
# 2026-03-24 17:00:00+00:00       100718.0
# 2026-03-24 18:00:00+00:00       100718.0
# 2026-03-24 19:00:00+00:00       100718.0
# 2026-03-24 20:00:00+00:00       101519.0
#
# [1687 rows x 8 columns]

# %%
plot, fig, ax, ax2, legend = make_secondary_axis_plot(engine="plotly")
plot(df["close"])
legend(show_date=True)
