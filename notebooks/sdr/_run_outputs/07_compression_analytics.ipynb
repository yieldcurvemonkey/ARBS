# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath("__file__")))
sys.path.insert(0, r"C:\Users\chris\clee\ARBS")


import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import _usd_swaps_common as sdr

sdr.notebook_setup()

START = datetime.datetime(2025, 4, 10, tzinfo=datetime.timezone.utc)
END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
CACHE_PATH = sdr.DEFAULT_CACHE_PATH

df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
print(f"Loaded {len(df):,} trades across {df['execution_date'].nunique()} trading days")
# Out:
# CACHE HIT...:   0%|          | 0/251 [00:00<?, ?it/s]
# CACHE HIT...:   0%|          | 1/251 [00:00<00:26,  9.60it/s]
# CACHE HIT...:   1%|          | 3/251 [00:00<00:16, 14.85it/s]
# CACHE HIT...: 100%|██████████| 251/251 [00:00<00:00, 828.63it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 20
#      17 END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
#      18 CACHE_PATH = sdr.DEFAULT_CACHE_PATH
# ---> 20 df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
#      21 print(f"Loaded {len(df):,} trades across {df['execution_date'].nunique()} trading days")
#
# File ~\clee\ARBS\notebooks\sdr\_usd_swaps_common.py:151, in load_usd_swaps(start, end, cache_path, curve_source, detect_packages)
#     134 """
#     135 Load and classify SDR trades for a date range.
#     136
#    (...)    148     is_spreadover, is_asset_swap
#     149 """
#     150 product = USD_SwapProduct()
# --> 151 df = product.build_classification_dataframe(
#     152     start=start,
#     153     end=end,
#     154     cache_path=cache_path,
#     155     detect_curve=detect_packages,
#     156     detect_fly=detect_packages,
#     157     detect_mms=detect_packages,
#     158     detect_invoice=detect_packages,
#     159     detect_mac=detect_packages,
#     160     detect_spreadover=detect_packages,
#     161     curve_source=curve_source,
#     162 )
#     164 if df.empty:
#     165     return df
#
# File ~\clee\ARBS\SDRUtils\products\usd\usd_swaps.py:697, in USD_SwapProduct.build_classification_dataframe(self, start, end, cache_path, detect_curve, detect_fly, detect_mms, detect_invoice, detect_mac, detect_spreadover, ignore_cache, merge_package_legs, use_v2_classification, **kwargs)
#     680 def build_classification_dataframe(
#     681     self,
#     682     start: datetime.datetime,
#    (...)    694     **kwargs: Any,
#     695 ):
#     696     sdr = SDRDataBuilder(cache_path=cache_path, show_tqdm=True)
# --> 697     raw_sdr_trades_df = sdr.grab_sdr_trades(
#     698         start_timestamp=start,
#     699         end_timestamp=end,
#     700         agency="CFTC",
#     701         asset_class="RATES",
#     702         filter_func=usd_swap_trades,
#     703         ignore_cache=ignore_cache,
#     704     )
#     706     if raw_sdr_trades_df.empty:
#     707         return raw_sdr_trades_df
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1167, in SDRDataBuilder.grab_sdr_trades(self, start_timestamp, end_timestamp, agency, asset_class, ts_col, filter_func, ignore_cache)
#    1164 dfs: List[pd.DataFrame] = []
#    1166 if hist_start_date <= hist_end_date:
# -> 1167     hist_df = self.grab_historical_sdr_trades(
#    1168         start_date=hist_start_date,
#    1169         end_date=hist_end_date,
#    1170         agency=agency,
#    1171         asset_class=asset_class,
#    1172         one_df=True,
#    1173         ignore_cache=ignore_cache,
#    1174     )
#    1175     if not hist_df.empty:
#    1176         mask = (hist_df[ts_col] >= start_ts) & (hist_df[ts_col] <= end_ts)
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1109, in SDRDataBuilder.grab_historical_sdr_trades(self, start_date, end_date, agency, asset_class, one_df, ignore_cache)
#    1107 fresh: Dict[date, pd.DataFrame] | pd.DataFrame = {}
#    1108 if to_fetch:
# -> 1109     fresh = self.dtcc_sdr_fetcher.fetch_historical_reports(
#    1110         start_date=min(to_fetch),
#    1111         end_date=max(to_fetch),
#    1112         agency=agency,
#    1113         asset_class=asset_class,
#    1114         max_concurrent_tasks=self._max_concurrent_tasks,
#    1115         max_keepalive_connections=self._max_keepalive_connections,
#    1116         max_extraction_workers=self._max_extraction_workers,
#    1117         use_pyarrow=True,
#    1118         one_df=False,
#    1119         show_tqdm=self._show_tqdm,
#    1120     )
#    1121     # Only persist when using cache
#    1122     if not ignore_cache:
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:412, in DTCCFetcher.fetch_historical_reports(self, start_date, end_date, agency, asset_class, max_concurrent_tasks, max_keepalive_connections, parallelize, max_extraction_workers, use_pyarrow, one_df, show_tqdm, ts_col)
#     398         results = await self._run_fetch_tasks(
#     399             date_strings=date_strings,
#     400             agency=agency,
#    (...)    408             tqdm_desc="FETCHING HISTORICAL SDR REPORTS..." if show_tqdm else None,
#     409         )
#     410         return results
# --> 412 all_results = asyncio.run(run())
#     413 merged_data: Dict[date, pd.DataFrame] = {}
#     414 for daily_dict in all_results:
#
# File ~\anaconda3\envs\stir\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ## 1. Compression Identification
# Multi-signal approach: lifecycle events (TERM/CORR), platform signatures, notional rounding.
# ~1/3 of all SDR-reported trades are compression.

# %%
# Signal 1: Non-NEWT action types (lifecycle events)
non_newt = df[df["event_action"].astype(str).str.upper() != "NEWT"] if "event_action" in df.columns else pd.DataFrame()

# Signal 2: NEWT trades (potential new risk)
newt = sdr.filter_new_risk(df)

# Signal 3: Reset optimization (tenor < 6M)
reset_opt = sdr.filter_reset_optimization(newt)
non_reset = newt[~newt.index.isin(reset_opt.index)]

print(f"Total trades: {len(df):,}")
print(f"  NEWT (new risk candidates): {len(newt):,} ({len(newt)/len(df)*100:.1f}%)")
print(f"  Non-NEWT (lifecycle/compression): {len(non_newt):,} ({len(non_newt)/len(df)*100:.1f}%)")
print(f"  Reset optimization (< 6M tenor): {len(reset_opt):,} ({len(reset_opt)/len(newt)*100:.1f}% of NEWT)")
print(f"  Clean new risk: {len(non_reset):,} ({len(non_reset)/len(df)*100:.1f}% of total)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Signal 1: Non-NEWT action types (lifecycle events)
# ----> 2 non_newt = df[df["event_action"].astype(str).str.upper() != "NEWT"] if "event_action" in df.columns else pd.DataFrame()
#       4 # Signal 2: NEWT trades (potential new risk)
#       5 newt = sdr.filter_new_risk(df)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 2. Compression vs New-Risk Volume

# %%
clean_daily = non_reset.groupby("execution_date")["dv01"].sum()
reset_daily = reset_opt.groupby("execution_date")["dv01"].sum()
lifecycle_daily = non_newt.groupby("execution_date")["dv01"].sum() if not non_newt.empty else pd.Series(dtype=float)

combined = pd.DataFrame({
    "Clean New Risk": clean_daily,
    "Reset Optimization": reset_daily,
    "Lifecycle (TERM/CORR/MODI)": lifecycle_daily,
}).fillna(0).sort_index()
combined.index = pd.to_datetime(combined.index)

sdr.plot_stacked_area(
    combined,
    "Daily DV01: Clean vs Reset Optimization vs Lifecycle",
    color_map={"Clean New Risk": "#4C78A8", "Reset Optimization": "#BFBFBF", "Lifecycle (TERM/CORR/MODI)": "#F58518"},
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 clean_daily = non_reset.groupby("execution_date")["dv01"].sum()
#       2 reset_daily = reset_opt.groupby("execution_date")["dv01"].sum()
#       3 lifecycle_daily = non_newt.groupby("execution_date")["dv01"].sum() if not non_newt.empty else pd.Series(dtype=float)
#
# NameError: name 'non_reset' is not defined

# %% [markdown]
# ## 3. Platform Market Share
# TradeWeb (~46%), OSTTRA (~27%), bilateral (~22%), Bloomberg (~4%).

# %%
if "platform_identifier" in df.columns:
    platform_dv01 = df.groupby("platform_identifier")["dv01"].sum().sort_values(ascending=False)
    top_platforms = platform_dv01.head(10)
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    
    # Bar chart
    top_platforms.plot.barh(ax=axes[0], color="#4C78A8", alpha=0.8)
    axes[0].set_title("DV01 by Platform (Top 10)")
    axes[0].set_xlabel("DV01 ($)")
    
    # Pie chart
    top_platforms.plot.pie(ax=axes[1], autopct="%1.1f%%", startangle=90)
    axes[1].set_ylabel("")
    axes[1].set_title("Platform Market Share (DV01)")
    
    plt.tight_layout()
    plt.show()
else:
    print("platform_identifier column not available.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 if "platform_identifier" in df.columns:
#       2     platform_dv01 = df.groupby("platform_identifier")["dv01"].sum().sort_values(ascending=False)
#       3     top_platforms = platform_dv01.head(10)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 4. Reset Optimization Detection
# Single-period swaps and FRA-like activity. Weekday clustering analysis.

# %%
if not reset_opt.empty:
    reset_opt_dt = reset_opt.copy()
    reset_opt_dt["execution_date_dt"] = pd.to_datetime(reset_opt_dt["execution_date"])
    reset_opt_dt["weekday"] = reset_opt_dt["execution_date_dt"].dt.day_name()
    
    weekday_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
    weekday_counts = reset_opt_dt.groupby("weekday").agg(
        trade_count=("dv01", "size"),
        total_dv01=("dv01", "sum"),
    ).reindex(weekday_order)
    
    fig, ax = plt.subplots(figsize=(10, 5))
    weekday_counts["trade_count"].plot.bar(ax=ax, color="#E45756", alpha=0.8)
    ax.set_title("Reset Optimization Trade Count by Weekday")
    ax.set_ylabel("Trade Count")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    
    print(weekday_counts.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 if not reset_opt.empty:
#       2     reset_opt_dt = reset_opt.copy()
#       3     reset_opt_dt["execution_date_dt"] = pd.to_datetime(reset_opt_dt["execution_date"])
#
# NameError: name 'reset_opt' is not defined

# %% [markdown]
# ## 5. Compression-Adjusted "Clean" Volume
# The metric that matters for flow analysis — stripping compression and reset optimization.

# %%
raw_daily = df.groupby("execution_date")["dv01"].sum()
clean_daily_final = non_reset.groupby("execution_date")["dv01"].sum()

comparison = pd.DataFrame({
    "Raw Reported": raw_daily,
    "Clean (New Risk Only)": clean_daily_final,
}).fillna(0).sort_index()
comparison.index = pd.to_datetime(comparison.index)

fig, ax = plt.subplots(figsize=(14, 6))
comparison["Raw Reported"].plot(ax=ax, alpha=0.4, color="#BFBFBF", label="Raw Reported")
comparison["Clean (New Risk Only)"].plot(ax=ax, color="#4C78A8", linewidth=1.5, label="Clean New Risk")
ax.set_title("Raw vs Clean Volume (DV01)")
ax.set_ylabel("DV01 ($)")
ax.legend()
plt.tight_layout()
plt.show()

ratio = clean_daily_final.sum() / raw_daily.sum() * 100
print(f"Clean/Raw ratio: {ratio:.1f}% \u2014 {100-ratio:.1f}% of reported volume is non-new-risk")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 raw_daily = df.groupby("execution_date")["dv01"].sum()
#       2 clean_daily_final = non_reset.groupby("execution_date")["dv01"].sum()
#       4 comparison = pd.DataFrame({
#       5     "Raw Reported": raw_daily,
#       6     "Clean (New Risk Only)": clean_daily_final,
#       7 }).fillna(0).sort_index()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 6. Gross-to-Net Compression Ratio
# Higher ratio = more portfolio optimization activity.

# %%
# Align on datetime index
raw_s = raw_daily.copy()
raw_s.index = pd.to_datetime(raw_s.index)
clean_s = clean_daily_final.copy()
clean_s.index = pd.to_datetime(clean_s.index)

monthly = pd.DataFrame({
    "raw": raw_s.resample("ME").sum(),
    "clean": clean_s.resample("ME").sum(),
})
monthly["compression_pct"] = (1 - monthly["clean"] / monthly["raw"]) * 100

fig, ax = plt.subplots(figsize=(14, 5))
monthly["compression_pct"].plot.bar(ax=ax, color="#E45756", alpha=0.8)
ax.set_title("Monthly Compression as % of Total Volume")
ax.set_ylabel("Compression %")
ax.axhline(33, color="black", linestyle="--", alpha=0.5, label="33% benchmark")
ax.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Align on datetime index
# ----> 2 raw_s = raw_daily.copy()
#       3 raw_s.index = pd.to_datetime(raw_s.index)
#       4 clean_s = clean_daily_final.copy()
#
# NameError: name 'raw_daily' is not defined
