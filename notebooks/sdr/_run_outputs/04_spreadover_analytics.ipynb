# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath("__file__")))
sys.path.insert(0, r"C:\Users\chris\clee\ARBS")


import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import _usd_swaps_common as sdr

sdr.notebook_setup()

START = datetime.datetime(2025, 4, 10, tzinfo=datetime.timezone.utc)
END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
CACHE_PATH = sdr.DEFAULT_CACHE_PATH

df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
df = sdr.filter_new_risk(df)
print(f"Loaded {len(df):,} new-risk trades")
# Out:
# CACHE HIT...:   0%|          | 0/251 [00:00<?, ?it/s]
# CACHE HIT...:   0%|          | 1/251 [00:00<00:25,  9.69it/s]
# CACHE HIT...:   1%|          | 3/251 [00:00<00:17, 14.35it/s]
# CACHE HIT...: 100%|██████████| 251/251 [00:00<00:00, 801.91it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 20
#      17 END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
#      18 CACHE_PATH = sdr.DEFAULT_CACHE_PATH
# ---> 20 df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
#      21 df = sdr.filter_new_risk(df)
#      22 print(f"Loaded {len(df):,} new-risk trades")
#
# File ~\clee\ARBS\notebooks\sdr\_usd_swaps_common.py:151, in load_usd_swaps(start, end, cache_path, curve_source, detect_packages)
#     134 """
#     135 Load and classify SDR trades for a date range.
#     136
#    (...)    148     is_spreadover, is_asset_swap
#     149 """
#     150 product = USD_SwapProduct()
# --> 151 df = product.build_classification_dataframe(
#     152     start=start,
#     153     end=end,
#     154     cache_path=cache_path,
#     155     detect_curve=detect_packages,
#     156     detect_fly=detect_packages,
#     157     detect_mms=detect_packages,
#     158     detect_invoice=detect_packages,
#     159     detect_mac=detect_packages,
#     160     detect_spreadover=detect_packages,
#     161     curve_source=curve_source,
#     162 )
#     164 if df.empty:
#     165     return df
#
# File ~\clee\ARBS\SDRUtils\products\usd\usd_swaps.py:697, in USD_SwapProduct.build_classification_dataframe(self, start, end, cache_path, detect_curve, detect_fly, detect_mms, detect_invoice, detect_mac, detect_spreadover, ignore_cache, merge_package_legs, use_v2_classification, **kwargs)
#     680 def build_classification_dataframe(
#     681     self,
#     682     start: datetime.datetime,
#    (...)    694     **kwargs: Any,
#     695 ):
#     696     sdr = SDRDataBuilder(cache_path=cache_path, show_tqdm=True)
# --> 697     raw_sdr_trades_df = sdr.grab_sdr_trades(
#     698         start_timestamp=start,
#     699         end_timestamp=end,
#     700         agency="CFTC",
#     701         asset_class="RATES",
#     702         filter_func=usd_swap_trades,
#     703         ignore_cache=ignore_cache,
#     704     )
#     706     if raw_sdr_trades_df.empty:
#     707         return raw_sdr_trades_df
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1167, in SDRDataBuilder.grab_sdr_trades(self, start_timestamp, end_timestamp, agency, asset_class, ts_col, filter_func, ignore_cache)
#    1164 dfs: List[pd.DataFrame] = []
#    1166 if hist_start_date <= hist_end_date:
# -> 1167     hist_df = self.grab_historical_sdr_trades(
#    1168         start_date=hist_start_date,
#    1169         end_date=hist_end_date,
#    1170         agency=agency,
#    1171         asset_class=asset_class,
#    1172         one_df=True,
#    1173         ignore_cache=ignore_cache,
#    1174     )
#    1175     if not hist_df.empty:
#    1176         mask = (hist_df[ts_col] >= start_ts) & (hist_df[ts_col] <= end_ts)
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1109, in SDRDataBuilder.grab_historical_sdr_trades(self, start_date, end_date, agency, asset_class, one_df, ignore_cache)
#    1107 fresh: Dict[date, pd.DataFrame] | pd.DataFrame = {}
#    1108 if to_fetch:
# -> 1109     fresh = self.dtcc_sdr_fetcher.fetch_historical_reports(
#    1110         start_date=min(to_fetch),
#    1111         end_date=max(to_fetch),
#    1112         agency=agency,
#    1113         asset_class=asset_class,
#    1114         max_concurrent_tasks=self._max_concurrent_tasks,
#    1115         max_keepalive_connections=self._max_keepalive_connections,
#    1116         max_extraction_workers=self._max_extraction_workers,
#    1117         use_pyarrow=True,
#    1118         one_df=False,
#    1119         show_tqdm=self._show_tqdm,
#    1120     )
#    1121     # Only persist when using cache
#    1122     if not ignore_cache:
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:412, in DTCCFetcher.fetch_historical_reports(self, start_date, end_date, agency, asset_class, max_concurrent_tasks, max_keepalive_connections, parallelize, max_extraction_workers, use_pyarrow, one_df, show_tqdm, ts_col)
#     398         results = await self._run_fetch_tasks(
#     399             date_strings=date_strings,
#     400             agency=agency,
#    (...)    408             tqdm_desc="FETCHING HISTORICAL SDR REPORTS..." if show_tqdm else None,
#     409         )
#     410         return results
# --> 412 all_results = asyncio.run(run())
#     413 merged_data: Dict[date, pd.DataFrame] = {}
#     414 for daily_dict in all_results:
#
# File ~\anaconda3\envs\stir\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ## 1. Spreadover Identification
# Spreadovers = swap spread trades vs on-the-run Treasuries.
# Dominant D2D product (~70% of interdealer flow). Identified via package_indicator + package_transaction_spread fields.

# %%
spreadovers = sdr.filter_spreadovers(df)
non_spreadovers = df[~df.index.isin(spreadovers.index)]

print(f"Spreadovers: {len(spreadovers):,} trades ({len(spreadovers)/len(df)*100:.1f}%)")
print(f"  DV01: {sdr.format_dv01(spreadovers['dv01'].sum())} ({spreadovers['dv01'].sum()/df['dv01'].sum()*100:.1f}% of total)")
print(f"Non-spreadovers: {len(non_spreadovers):,}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 spreadovers = sdr.filter_spreadovers(df)
#       2 non_spreadovers = df[~df.index.isin(spreadovers.index)]
#       4 print(f"Spreadovers: {len(spreadovers):,} trades ({len(spreadovers)/len(df)*100:.1f}%)")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 2. VWAP Tracking
# Volume-weighted average rate per tenor, daily. Delta vs prior day + rolling average.

# %%
sprd_rates = spreadovers[pd.to_numeric(spreadovers["fixed_rate"], errors="coerce").notna()].copy()
sprd_rates["fixed_rate"] = pd.to_numeric(sprd_rates["fixed_rate"])

daily_vwaps = sdr.daily_vwap(sprd_rates, group_col="tenor_label")

for tenor in ["2Y", "5Y", "10Y", "30Y"]:
    tv = daily_vwaps[daily_vwaps["tenor_label"] == tenor].set_index("execution_date")["vwap"].sort_index()
    if len(tv) < 5:
        continue
    tv.index = pd.to_datetime(tv.index)
    
    fig, ax = plt.subplots(figsize=(14, 4))
    ax.plot(tv.index, tv.values, color="#4C78A8", linewidth=1, label="VWAP")
    ma20 = tv.rolling(20, min_periods=3).mean()
    ax.plot(ma20.index, ma20.values, color="#F58518", linewidth=1.5, linestyle="--", label="20d MA")
    ax.set_title(f"{tenor} Spreadover VWAP")
    ax.set_ylabel("Fixed Rate")
    ax.legend()
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sprd_rates = spreadovers[pd.to_numeric(spreadovers["fixed_rate"], errors="coerce").notna()].copy()
#       2 sprd_rates["fixed_rate"] = pd.to_numeric(sprd_rates["fixed_rate"])
#       4 daily_vwaps = sdr.daily_vwap(sprd_rates, group_col="tenor_label")
#
# NameError: name 'spreadovers' is not defined

# %% [markdown]
# ## 3. Trade Count + DV01 Time Series
# Daily spreadover activity by tenor. Flag "Swapalypse" events (>2σ volume).

# %%
sprd_pivot = sdr.daily_dv01_by_group(spreadovers, "tenor_label")
sprd_pivot = sprd_pivot[[c for c in sdr.BENCHMARK_TENORS if c in sprd_pivot.columns]]

sdr.plot_stacked_area(sprd_pivot, "Daily Spreadover DV01 by Tenor")
plt.show()

# Swapalypse detection
sprd_daily = spreadovers.groupby("execution_date")["dv01"].sum()
sprd_daily.index = pd.to_datetime(sprd_daily.index)
z = sdr.rolling_zscore(sprd_daily, window=20)
swapalypse = z[z > 2].sort_values(ascending=False)

if not swapalypse.empty:
    print(f"\n'Swapalypse' days (spreadover volume >2\u03c3): {len(swapalypse)}")
    for date, z_val in swapalypse.head(10).items():
        vol = sprd_daily.get(date, 0)
        print(f"  {date.date()}: Z={z_val:+.1f}, DV01={sdr.format_dv01(vol)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sprd_pivot = sdr.daily_dv01_by_group(spreadovers, "tenor_label")
#       2 sprd_pivot = sprd_pivot[[c for c in sdr.BENCHMARK_TENORS if c in sprd_pivot.columns]]
#       4 sdr.plot_stacked_area(sprd_pivot, "Daily Spreadover DV01 by Tenor")
#
# NameError: name 'spreadovers' is not defined

# %% [markdown]
# ## 4. Tenor Distribution
# Which maturities dominate spreadover flow? Track share shifts over time.

# %%
tenor_dv01 = spreadovers.groupby("tenor_label")["dv01"].sum().sort_values(ascending=False)
top_tenors = tenor_dv01.head(10)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
top_tenors.plot.bar(ax=axes[0], color="#72B7B2", alpha=0.8)
axes[0].set_title("Spreadover DV01 by Tenor")
axes[0].set_ylabel("DV01 ($)")

top_tenors.plot.pie(ax=axes[1], autopct="%1.1f%%", startangle=90)
axes[1].set_ylabel("")
axes[1].set_title("Spreadover Tenor Distribution")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tenor_dv01 = spreadovers.groupby("tenor_label")["dv01"].sum().sort_values(ascending=False)
#       2 top_tenors = tenor_dv01.head(10)
#       4 fig, axes = plt.subplots(1, 2, figsize=(14, 6))
#
# NameError: name 'spreadovers' is not defined

# %% [markdown]
# ## 5. Spreadover-to-Outright Ratio
# What fraction of total flow is spreadovers? Higher = more relative-value activity.

# %%
sprd_daily_dv01 = spreadovers.groupby("execution_date")["dv01"].sum()
total_daily_dv01 = df.groupby("execution_date")["dv01"].sum()

ratio = (sprd_daily_dv01 / total_daily_dv01 * 100).fillna(0)
ratio.index = pd.to_datetime(ratio.index)

fig, ax = plt.subplots(figsize=(14, 5))
ax.bar(ratio.index, ratio.values, alpha=0.4, color="#72B7B2")
ma20 = ratio.rolling(20, min_periods=3).mean()
ax.plot(ma20.index, ma20.values, color="#E45756", linewidth=2, label="20d MA")
ax.set_title("Spreadover as % of Total DV01")
ax.set_ylabel("Spreadover %")
ax.legend()
plt.tight_layout()
plt.show()

print(f"Average spreadover share: {ratio.mean():.1f}%")
print(f"Current (last 20d): {ratio.tail(20).mean():.1f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sprd_daily_dv01 = spreadovers.groupby("execution_date")["dv01"].sum()
#       2 total_daily_dv01 = df.groupby("execution_date")["dv01"].sum()
#       4 ratio = (sprd_daily_dv01 / total_daily_dv01 * 100).fillna(0)
#
# NameError: name 'spreadovers' is not defined
