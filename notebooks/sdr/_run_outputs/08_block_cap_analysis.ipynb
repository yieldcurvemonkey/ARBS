# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath("__file__")))
sys.path.insert(0, r"C:\Users\chris\clee\ARBS")


import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import _usd_swaps_common as sdr

sdr.notebook_setup()

# Include pre/post Oct 2024 recalibration for regime analysis
START = datetime.datetime(2025, 4, 10, tzinfo=datetime.timezone.utc)
END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
CACHE_PATH = sdr.DEFAULT_CACHE_PATH
RECALIBRATION_DATE = datetime.date(2024, 10, 1)

df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
df = sdr.filter_new_risk(df)
print(f"Loaded {len(df):,} new-risk trades")
# Out:
# CACHE HIT...:   0%|          | 0/251 [00:00<?, ?it/s]
# CACHE HIT...:   0%|          | 1/251 [00:00<00:29,  8.61it/s]
# CACHE HIT...:   1%|          | 3/251 [00:00<00:17, 14.01it/s]
# CACHE HIT...: 100%|██████████| 251/251 [00:00<00:00, 793.88it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 22
#      19 CACHE_PATH = sdr.DEFAULT_CACHE_PATH
#      20 RECALIBRATION_DATE = datetime.date(2024, 10, 1)
# ---> 22 df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
#      23 df = sdr.filter_new_risk(df)
#      24 print(f"Loaded {len(df):,} new-risk trades")
#
# File ~\clee\ARBS\notebooks\sdr\_usd_swaps_common.py:151, in load_usd_swaps(start, end, cache_path, curve_source, detect_packages)
#     134 """
#     135 Load and classify SDR trades for a date range.
#     136
#    (...)    148     is_spreadover, is_asset_swap
#     149 """
#     150 product = USD_SwapProduct()
# --> 151 df = product.build_classification_dataframe(
#     152     start=start,
#     153     end=end,
#     154     cache_path=cache_path,
#     155     detect_curve=detect_packages,
#     156     detect_fly=detect_packages,
#     157     detect_mms=detect_packages,
#     158     detect_invoice=detect_packages,
#     159     detect_mac=detect_packages,
#     160     detect_spreadover=detect_packages,
#     161     curve_source=curve_source,
#     162 )
#     164 if df.empty:
#     165     return df
#
# File ~\clee\ARBS\SDRUtils\products\usd\usd_swaps.py:697, in USD_SwapProduct.build_classification_dataframe(self, start, end, cache_path, detect_curve, detect_fly, detect_mms, detect_invoice, detect_mac, detect_spreadover, ignore_cache, merge_package_legs, use_v2_classification, **kwargs)
#     680 def build_classification_dataframe(
#     681     self,
#     682     start: datetime.datetime,
#    (...)    694     **kwargs: Any,
#     695 ):
#     696     sdr = SDRDataBuilder(cache_path=cache_path, show_tqdm=True)
# --> 697     raw_sdr_trades_df = sdr.grab_sdr_trades(
#     698         start_timestamp=start,
#     699         end_timestamp=end,
#     700         agency="CFTC",
#     701         asset_class="RATES",
#     702         filter_func=usd_swap_trades,
#     703         ignore_cache=ignore_cache,
#     704     )
#     706     if raw_sdr_trades_df.empty:
#     707         return raw_sdr_trades_df
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1167, in SDRDataBuilder.grab_sdr_trades(self, start_timestamp, end_timestamp, agency, asset_class, ts_col, filter_func, ignore_cache)
#    1164 dfs: List[pd.DataFrame] = []
#    1166 if hist_start_date <= hist_end_date:
# -> 1167     hist_df = self.grab_historical_sdr_trades(
#    1168         start_date=hist_start_date,
#    1169         end_date=hist_end_date,
#    1170         agency=agency,
#    1171         asset_class=asset_class,
#    1172         one_df=True,
#    1173         ignore_cache=ignore_cache,
#    1174     )
#    1175     if not hist_df.empty:
#    1176         mask = (hist_df[ts_col] >= start_ts) & (hist_df[ts_col] <= end_ts)
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1109, in SDRDataBuilder.grab_historical_sdr_trades(self, start_date, end_date, agency, asset_class, one_df, ignore_cache)
#    1107 fresh: Dict[date, pd.DataFrame] | pd.DataFrame = {}
#    1108 if to_fetch:
# -> 1109     fresh = self.dtcc_sdr_fetcher.fetch_historical_reports(
#    1110         start_date=min(to_fetch),
#    1111         end_date=max(to_fetch),
#    1112         agency=agency,
#    1113         asset_class=asset_class,
#    1114         max_concurrent_tasks=self._max_concurrent_tasks,
#    1115         max_keepalive_connections=self._max_keepalive_connections,
#    1116         max_extraction_workers=self._max_extraction_workers,
#    1117         use_pyarrow=True,
#    1118         one_df=False,
#    1119         show_tqdm=self._show_tqdm,
#    1120     )
#    1121     # Only persist when using cache
#    1122     if not ignore_cache:
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:412, in DTCCFetcher.fetch_historical_reports(self, start_date, end_date, agency, asset_class, max_concurrent_tasks, max_keepalive_connections, parallelize, max_extraction_workers, use_pyarrow, one_df, show_tqdm, ts_col)
#     398         results = await self._run_fetch_tasks(
#     399             date_strings=date_strings,
#     400             agency=agency,
#    (...)    408             tqdm_desc="FETCHING HISTORICAL SDR REPORTS..." if show_tqdm else None,
#     409         )
#     410         return results
# --> 412 all_results = asyncio.run(run())
#     413 merged_data: Dict[date, pd.DataFrame] = {}
#     414 for daily_dict in all_results:
#
# File ~\anaconda3\envs\stir\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ## 1. Block Trade Identification
# Oct 2024: CFTC recalibrated block thresholds +64% DV01. Capped trades dropped from 8% to 2%.

# %%
blocks = sdr.filter_blocks(df)
non_blocks = df[~df.index.isin(blocks.index)]

print(f"Block trades: {len(blocks):,} ({len(blocks)/len(df)*100:.1f}%)")
print(f"  Block DV01: {sdr.format_dv01(blocks['dv01'].sum())} ({blocks['dv01'].sum()/df['dv01'].sum()*100:.1f}%)")
print(f"Non-block trades: {len(non_blocks):,}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 blocks = sdr.filter_blocks(df)
#       2 non_blocks = df[~df.index.isin(blocks.index)]
#       4 print(f"Block trades: {len(blocks):,} ({len(blocks)/len(df)*100:.1f}%)")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 2. Capped Notional Detection
# Fraction of trades with capped notional — obscures true trade size.

# %%
capped = sdr.filter_capped(df)
print(f"Capped notional trades: {len(capped):,} ({len(capped)/len(df)*100:.1f}%)")
print(f"  Capped DV01: {sdr.format_dv01(capped['dv01'].sum())}")

# Daily capped percentage
capped_daily = capped.groupby("execution_date").size()
total_daily = df.groupby("execution_date").size()
capped_pct = (capped_daily / total_daily * 100).fillna(0)
capped_pct.index = pd.to_datetime(capped_pct.index)

fig, ax = plt.subplots(figsize=(14, 4))
ax.bar(capped_pct.index, capped_pct.values, alpha=0.6, color="#E45756")
ax.axvline(pd.Timestamp(RECALIBRATION_DATE), color="black", linestyle="--", linewidth=2, label="Oct 2024 Recalibration")
ax.set_title("Daily % of Trades with Capped Notional")
ax.set_ylabel("Capped %")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 capped = sdr.filter_capped(df)
#       2 print(f"Capped notional trades: {len(capped):,} ({len(capped)/len(df)*100:.1f}%)")
#       3 print(f"  Capped DV01: {sdr.format_dv01(capped['dv01'].sum())}")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Block Size Distribution by Tenor
# Histogram of block trade notionals. Overlay CFTC threshold lines.

# %%
if not blocks.empty:
    for tenor in ["5Y", "10Y", "30Y"]:
        t_blocks = blocks[blocks["tenor_label"] == tenor]
        if len(t_blocks) < 5:
            continue
        
        notionals = pd.to_numeric(t_blocks["notional"], errors="coerce").dropna() / 1e6
        
        fig, ax = plt.subplots(figsize=(10, 4))
        notionals.clip(upper=notionals.quantile(0.95)).hist(ax=ax, bins=30, color="#4C78A8", alpha=0.8)
        ax.set_title(f"{tenor} Block Trade Notional Distribution")
        ax.set_xlabel("Notional ($M)")
        ax.set_ylabel("Count")
        plt.tight_layout()
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 if not blocks.empty:
#       2     for tenor in ["5Y", "10Y", "30Y"]:
#       3         t_blocks = blocks[blocks["tenor_label"] == tenor]
#
# NameError: name 'blocks' is not defined

# %% [markdown]
# ## 4. Regime Change Analysis
# Before/after Oct 2024: block count, capped percentage, average visible notional.

# %%
pre = df[pd.to_datetime(df["execution_date"]) < pd.Timestamp(RECALIBRATION_DATE)]
post = df[pd.to_datetime(df["execution_date"]) >= pd.Timestamp(RECALIBRATION_DATE)]

pre_blocks = sdr.filter_blocks(pre)
post_blocks = sdr.filter_blocks(post)
pre_capped = sdr.filter_capped(pre)
post_capped = sdr.filter_capped(post)

pre_days = pre["execution_date"].nunique()
post_days = post["execution_date"].nunique()

regime = pd.DataFrame({
    "Pre-Oct 2024": {
        "Trading Days": pre_days,
        "Block % (count)": f"{len(pre_blocks)/len(pre)*100:.1f}%",
        "Block % (DV01)": f"{pre_blocks['dv01'].sum()/pre['dv01'].sum()*100:.1f}%",
        "Capped % (count)": f"{len(pre_capped)/len(pre)*100:.1f}%",
        "Avg Daily Block Count": f"{len(pre_blocks)/max(pre_days,1):.0f}",
    },
    "Post-Oct 2024": {
        "Trading Days": post_days,
        "Block % (count)": f"{len(post_blocks)/max(len(post),1)*100:.1f}%",
        "Block % (DV01)": f"{post_blocks['dv01'].sum()/max(post['dv01'].sum(),1)*100:.1f}%",
        "Capped % (count)": f"{len(post_capped)/max(len(post),1)*100:.1f}%",
        "Avg Daily Block Count": f"{len(post_blocks)/max(post_days,1):.0f}",
    },
})
display(regime.T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pre = df[pd.to_datetime(df["execution_date"]) < pd.Timestamp(RECALIBRATION_DATE)]
#       2 post = df[pd.to_datetime(df["execution_date"]) >= pd.Timestamp(RECALIBRATION_DATE)]
#       4 pre_blocks = sdr.filter_blocks(pre)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 5. True Volume Estimation
# Apply ~30% uplift to block notionals (per Clarus research).
# Block sizes are systematically underreported due to capping at CFTC thresholds.

# %%
UPLIFT_FACTOR = 1.30

block_notional = blocks.groupby("execution_date")["notional"].sum()
adjusted_block_notional = block_notional * UPLIFT_FACTOR
uplift = adjusted_block_notional - block_notional

non_block_notional = non_blocks.groupby("execution_date")["notional"].sum()
total_reported = block_notional + non_block_notional
total_adjusted = adjusted_block_notional + non_block_notional

combined = pd.DataFrame({
    "Reported": total_reported,
    "Adjusted (+30% blocks)": total_adjusted,
}).sort_index() / 1e9  # billions
combined.index = pd.to_datetime(combined.index)

fig, ax = plt.subplots(figsize=(14, 5))
combined.plot(ax=ax, alpha=0.6)
ax.set_title("Reported vs Adjusted Notional (30% Block Uplift)")
ax.set_ylabel("Notional ($B)")
plt.tight_layout()
plt.show()

total_uplift = uplift.sum()
print(f"Total block uplift: ${total_uplift/1e9:.1f}B additional notional estimated")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 UPLIFT_FACTOR = 1.30
# ----> 3 block_notional = blocks.groupby("execution_date")["notional"].sum()
#       4 adjusted_block_notional = block_notional * UPLIFT_FACTOR
#       5 uplift = adjusted_block_notional - block_notional
#
# NameError: name 'blocks' is not defined
