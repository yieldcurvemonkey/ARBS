# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath("__file__")))
sys.path.insert(0, r"C:\Users\chris\clee\ARBS")


import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import _usd_swaps_common as sdr
from SDRUtils.analytics.seasonality import get_fomc_dates

sdr.notebook_setup()

START = datetime.datetime(2025, 4, 10, tzinfo=datetime.timezone.utc)
END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
CACHE_PATH = sdr.DEFAULT_CACHE_PATH

df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
df = sdr.filter_new_risk(df)
print(f"Loaded {len(df):,} new-risk trades")
# Out:
# CACHE HIT...:   0%|          | 0/251 [00:00<?, ?it/s]
# CACHE HIT...:   0%|          | 1/251 [00:00<00:28,  8.88it/s]
# CACHE HIT...:   1%|          | 3/251 [00:00<00:18, 13.46it/s]
# CACHE HIT...: 100%|██████████| 251/251 [00:00<00:00, 765.15it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 21
#      18 END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
#      19 CACHE_PATH = sdr.DEFAULT_CACHE_PATH
# ---> 21 df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
#      22 df = sdr.filter_new_risk(df)
#      23 print(f"Loaded {len(df):,} new-risk trades")
#
# File ~\clee\ARBS\notebooks\sdr\_usd_swaps_common.py:151, in load_usd_swaps(start, end, cache_path, curve_source, detect_packages)
#     134 """
#     135 Load and classify SDR trades for a date range.
#     136
#    (...)    148     is_spreadover, is_asset_swap
#     149 """
#     150 product = USD_SwapProduct()
# --> 151 df = product.build_classification_dataframe(
#     152     start=start,
#     153     end=end,
#     154     cache_path=cache_path,
#     155     detect_curve=detect_packages,
#     156     detect_fly=detect_packages,
#     157     detect_mms=detect_packages,
#     158     detect_invoice=detect_packages,
#     159     detect_mac=detect_packages,
#     160     detect_spreadover=detect_packages,
#     161     curve_source=curve_source,
#     162 )
#     164 if df.empty:
#     165     return df
#
# File ~\clee\ARBS\SDRUtils\products\usd\usd_swaps.py:697, in USD_SwapProduct.build_classification_dataframe(self, start, end, cache_path, detect_curve, detect_fly, detect_mms, detect_invoice, detect_mac, detect_spreadover, ignore_cache, merge_package_legs, use_v2_classification, **kwargs)
#     680 def build_classification_dataframe(
#     681     self,
#     682     start: datetime.datetime,
#    (...)    694     **kwargs: Any,
#     695 ):
#     696     sdr = SDRDataBuilder(cache_path=cache_path, show_tqdm=True)
# --> 697     raw_sdr_trades_df = sdr.grab_sdr_trades(
#     698         start_timestamp=start,
#     699         end_timestamp=end,
#     700         agency="CFTC",
#     701         asset_class="RATES",
#     702         filter_func=usd_swap_trades,
#     703         ignore_cache=ignore_cache,
#     704     )
#     706     if raw_sdr_trades_df.empty:
#     707         return raw_sdr_trades_df
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1167, in SDRDataBuilder.grab_sdr_trades(self, start_timestamp, end_timestamp, agency, asset_class, ts_col, filter_func, ignore_cache)
#    1164 dfs: List[pd.DataFrame] = []
#    1166 if hist_start_date <= hist_end_date:
# -> 1167     hist_df = self.grab_historical_sdr_trades(
#    1168         start_date=hist_start_date,
#    1169         end_date=hist_end_date,
#    1170         agency=agency,
#    1171         asset_class=asset_class,
#    1172         one_df=True,
#    1173         ignore_cache=ignore_cache,
#    1174     )
#    1175     if not hist_df.empty:
#    1176         mask = (hist_df[ts_col] >= start_ts) & (hist_df[ts_col] <= end_ts)
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1109, in SDRDataBuilder.grab_historical_sdr_trades(self, start_date, end_date, agency, asset_class, one_df, ignore_cache)
#    1107 fresh: Dict[date, pd.DataFrame] | pd.DataFrame = {}
#    1108 if to_fetch:
# -> 1109     fresh = self.dtcc_sdr_fetcher.fetch_historical_reports(
#    1110         start_date=min(to_fetch),
#    1111         end_date=max(to_fetch),
#    1112         agency=agency,
#    1113         asset_class=asset_class,
#    1114         max_concurrent_tasks=self._max_concurrent_tasks,
#    1115         max_keepalive_connections=self._max_keepalive_connections,
#    1116         max_extraction_workers=self._max_extraction_workers,
#    1117         use_pyarrow=True,
#    1118         one_df=False,
#    1119         show_tqdm=self._show_tqdm,
#    1120     )
#    1121     # Only persist when using cache
#    1122     if not ignore_cache:
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:412, in DTCCFetcher.fetch_historical_reports(self, start_date, end_date, agency, asset_class, max_concurrent_tasks, max_keepalive_connections, parallelize, max_extraction_workers, use_pyarrow, one_df, show_tqdm, ts_col)
#     398         results = await self._run_fetch_tasks(
#     399             date_strings=date_strings,
#     400             agency=agency,
#    (...)    408             tqdm_desc="FETCHING HISTORICAL SDR REPORTS..." if show_tqdm else None,
#     409         )
#     410         return results
# --> 412 all_results = asyncio.run(run())
#     413 merged_data: Dict[date, pd.DataFrame] = {}
#     414 for daily_dict in all_results:
#
# File ~\anaconda3\envs\stir\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ## 1. SOFR vs FedFunds OIS Volume Split
# Daily DV01 by rate index. Track percentage of total in each category.
# 53% volume growth in SOFR-FF basis swaps to $14.4T in 2025.

# %%
sofr = sdr.filter_by_rate_index(df, "SOFR")
sofr_compound = sdr.filter_by_rate_index(df, "SOFR_COMPOUND")
ff = sdr.filter_by_rate_index(df, "FED_FUNDS")
ff_compound = sdr.filter_by_rate_index(df, "FED_FUNDS_COMPOUND")

sofr_all = pd.concat([sofr, sofr_compound])
ff_all = pd.concat([ff, ff_compound])

sofr_daily = sofr_all.groupby("execution_date")["dv01"].sum()
ff_daily = ff_all.groupby("execution_date")["dv01"].sum()

split = pd.DataFrame({"SOFR": sofr_daily, "FedFunds": ff_daily}).fillna(0).sort_index()
split.index = pd.to_datetime(split.index)

sdr.plot_stacked_area(split, "Daily DV01: SOFR vs FedFunds", color_map=sdr.RATE_INDEX_COLORS)
plt.show()

# Percentage split
split_pct = split.div(split.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 4))
split_pct["FedFunds"].rolling(20, min_periods=3).mean().plot(ax=ax, color="#F58518", linewidth=2)
ax.set_title("FedFunds Share of Total (20d Rolling Avg)")
ax.set_ylabel("FedFunds %")
ax.axhline(10, color="red", linestyle="--", alpha=0.5, label="10% reference")
ax.legend()
plt.tight_layout()
plt.show()

print(f"SOFR DV01: {sdr.format_dv01(sofr_all['dv01'].sum())} ({sofr_all['dv01'].sum()/(sofr_all['dv01'].sum()+ff_all['dv01'].sum())*100:.1f}%)")
print(f"FedFunds DV01: {sdr.format_dv01(ff_all['dv01'].sum())} ({ff_all['dv01'].sum()/(sofr_all['dv01'].sum()+ff_all['dv01'].sum())*100:.1f}%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sofr = sdr.filter_by_rate_index(df, "SOFR")
#       2 sofr_compound = sdr.filter_by_rate_index(df, "SOFR_COMPOUND")
#       3 ff = sdr.filter_by_rate_index(df, "FED_FUNDS")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 2. Basis Swap Volumes
# Filter to SOFR-FF basis swaps. DV01 by tenor.

# %%
basis = sdr.filter_by_basis_type(df, "SOFR_FF")
if not basis.empty:
    basis_daily = basis.groupby("execution_date")["dv01"].sum()
    basis_daily.index = pd.to_datetime(basis_daily.index)
    
    fig, ax = plt.subplots(figsize=(14, 5))
    ax.bar(basis_daily.index, basis_daily.values, alpha=0.6, color="#E45756")
    ma = basis_daily.rolling(20, min_periods=3).mean()
    ax.plot(ma.index, ma.values, color="black", linewidth=2, label="20d MA")
    ax.set_title("SOFR-FedFunds Basis Swap Daily DV01")
    ax.set_ylabel("DV01 ($)")
    ax.legend()
    plt.tight_layout()
    plt.show()
else:
    print("No SOFR_FF basis swaps found. Check if basis_type column is populated.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 basis = sdr.filter_by_basis_type(df, "SOFR_FF")
#       2 if not basis.empty:
#       3     basis_daily = basis.groupby("execution_date")["dv01"].sum()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Basis Activity Heatmap
# DV01 by tenor x month. Shows where on the curve basis is being traded.

# %%
if not basis.empty and "tenor_label" in basis.columns:
    basis_monthly = basis.copy()
    basis_monthly["month"] = pd.to_datetime(basis_monthly["execution_date"]).dt.to_period("M").astype(str)
    
    hm = basis_monthly.pivot_table(
        index="tenor_label", columns="month", values="dv01", aggfunc="sum", fill_value=0,
    )
    hm = hm.reindex([t for t in sdr.TENOR_ORDER if t in hm.index])
    
    sdr.plot_heatmap(hm / 1e6, "SOFR-FF Basis DV01 by Tenor x Month ($M)", cmap="YlOrRd", fmt=".1f")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 if not basis.empty and "tenor_label" in basis.columns:
#       2     basis_monthly = basis.copy()
#       3     basis_monthly["month"] = pd.to_datetime(basis_monthly["execution_date"]).dt.to_period("M").astype(str)
#
# NameError: name 'basis' is not defined

# %% [markdown]
# ## 4. Regime Detection
# Rolling FF/total ratio. Highlight spikes (e.g., Q3 2024: 7%→24%).

# %%
ff_ratio = (ff_daily / (sofr_daily + ff_daily) * 100).fillna(0)
ff_ratio.index = pd.to_datetime(ff_ratio.index)

fig, ax = plt.subplots(figsize=(14, 5))
ax.fill_between(ff_ratio.index, ff_ratio.values, alpha=0.3, color="#F58518")
ma = ff_ratio.rolling(20, min_periods=3).mean()
ax.plot(ma.index, ma.values, color="#F58518", linewidth=2, label="20d MA")
ax.set_title("FedFunds Share of USD Swap Volume (Regime Indicator)")
ax.set_ylabel("FedFunds %")
ax.legend()
plt.tight_layout()
plt.show()

# Detect regime shifts (large month-over-month changes)
monthly_ratio = ff_ratio.resample("ME").mean()
mom_change = monthly_ratio.diff()
big_shifts = mom_change[mom_change.abs() > 3]
if not big_shifts.empty:
    print("Significant regime shifts (>3pp monthly change):")
    for date, change in big_shifts.items():
        print(f"  {date.date()}: {change:+.1f}pp (from {monthly_ratio.get(date - pd.offsets.MonthEnd(1), np.nan):.1f}% to {monthly_ratio.get(date, np.nan):.1f}%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ff_ratio = (ff_daily / (sofr_daily + ff_daily) * 100).fillna(0)
#       2 ff_ratio.index = pd.to_datetime(ff_ratio.index)
#       4 fig, ax = plt.subplots(figsize=(14, 5))
#
# NameError: name 'ff_daily' is not defined

# %% [markdown]
# ## 5. FOMC Overlay
# Basis volumes and FF share around FOMC meeting dates.

# %%
fomc_dates = get_fomc_dates()
fomc_in_range = [d for d in fomc_dates if START.date() <= d <= END.date()]

if fomc_in_range:
    fig, ax = plt.subplots(figsize=(14, 5))
    ax.plot(ff_ratio.index, ff_ratio.values, color="#F58518", alpha=0.5, linewidth=0.8)
    ma_plot = ff_ratio.rolling(20, min_periods=3).mean()
    ax.plot(ma_plot.index, ma_plot.values, color="#F58518", linewidth=2)
    
    for fd in fomc_in_range:
        ax.axvline(pd.Timestamp(fd), color="red", linestyle="--", alpha=0.3, linewidth=0.8)
    
    ax.set_title("FedFunds Share with FOMC Meeting Dates")
    ax.set_ylabel("FedFunds %")
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 if fomc_in_range:
#       5     fig, ax = plt.subplots(figsize=(14, 5))
# ----> 6     ax.plot(ff_ratio.index, ff_ratio.values, color="#F58518", alpha=0.5, linewidth=0.8)
#       7     ma_plot = ff_ratio.rolling(20, min_periods=3).mean()
#       8     ax.plot(ma_plot.index, ma_plot.values, color="#F58518", linewidth=2)
#
# NameError: name 'ff_ratio' is not defined
