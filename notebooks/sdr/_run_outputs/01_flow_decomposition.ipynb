# %%
import nest_asyncio
nest_asyncio.apply()

import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath("__file__")))
sys.path.insert(0, r"C:\Users\chris\clee\ARBS")


import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import _usd_swaps_common as sdr

sdr.notebook_setup()

# --- Parameters ---
START = datetime.datetime(2025, 4, 10, tzinfo=datetime.timezone.utc)
END = datetime.datetime(2026, 4, 10, 23, 59, 59, tzinfo=datetime.timezone.utc)
CACHE_PATH = sdr.DEFAULT_CACHE_PATH

# %%
df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
print(f"Loaded {len(df):,} classified trades from {df['execution_date'].nunique()} trading days")
print(f"Total DV01: {sdr.format_dv01(df['dv01'].sum())}")
print(f"Columns: {list(df.columns)}")
# Out:
# CACHE HIT...:   0%|          | 0/251 [00:00<?, ?it/s]
# CACHE HIT...:   0%|          | 1/251 [00:00<00:30,  8.28it/s]
# CACHE HIT...:   1%|          | 3/251 [00:00<00:18, 13.63it/s]
# CACHE HIT...:   2%|▏         | 5/251 [00:00<00:16, 14.57it/s]
# CACHE HIT...:   3%|▎         | 8/251 [00:00<00:12, 18.77it/s]
# CACHE HIT...:   4%|▍         | 10/251 [00:00<00:13, 17.67it/s]
# CACHE HIT...:   5%|▍         | 12/251 [00:00<00:13, 17.30it/s]
# CACHE HIT...:   6%|▌         | 14/251 [00:00<00:14, 16.10it/s]
# CACHE HIT...:   6%|▋         | 16/251 [00:00<00:13, 17.09it/s]
# CACHE HIT...:   8%|▊         | 19/251 [00:01<00:12, 18.69it/s]
# CACHE HIT...:   8%|▊         | 21/251 [00:01<00:12, 17.84it/s]
# CACHE HIT...:   9%|▉         | 23/251 [00:01<00:12, 18.00it/s]
# CACHE HIT...:  10%|▉         | 25/251 [00:01<00:13, 16.55it/s]
# CACHE HIT...:  11%|█         | 27/251 [00:01<00:13, 16.34it/s]
# CACHE HIT...:  12%|█▏        | 29/251 [00:01<00:13, 16.17it/s]
# CACHE HIT...:  12%|█▏        | 31/251 [00:01<00:13, 16.22it/s]
# CACHE HIT...:  13%|█▎        | 33/251 [00:01<00:12, 16.89it/s]
# CACHE HIT...:  14%|█▍        | 35/251 [00:02<00:13, 16.57it/s]
# CACHE HIT...:  15%|█▌        | 38/251 [00:02<00:12, 17.04it/s]
# CACHE HIT...:  16%|█▌        | 40/251 [00:02<00:12, 16.50it/s]
# CACHE HIT...:  17%|█▋        | 43/251 [00:02<00:11, 17.43it/s]
# CACHE HIT...:  18%|█▊        | 45/251 [00:02<00:12, 16.77it/s]
# CACHE HIT...:  19%|█▉        | 48/251 [00:02<00:11, 17.22it/s]
# CACHE HIT...:  20%|█▉        | 50/251 [00:02<00:11, 17.82it/s]
# CACHE HIT...:  21%|██        | 52/251 [00:03<00:11, 17.48it/s]
# CACHE HIT...:  22%|██▏       | 54/251 [00:03<00:11, 17.28it/s]
# CACHE HIT...:  22%|██▏       | 56/251 [00:03<00:11, 17.58it/s]
# CACHE HIT...:  23%|██▎       | 58/251 [00:03<00:11, 17.23it/s]
# CACHE HIT...:  24%|██▍       | 61/251 [00:03<00:10, 17.57it/s]
# CACHE HIT...:  25%|██▌       | 63/251 [00:03<00:10, 17.63it/s]
# CACHE HIT...:  26%|██▋       | 66/251 [00:03<00:10, 18.10it/s]
# CACHE HIT...:  27%|██▋       | 68/251 [00:03<00:10, 17.95it/s]
# CACHE HIT...:  28%|██▊       | 70/251 [00:04<00:10, 17.88it/s]
# CACHE HIT...:  29%|██▊       | 72/251 [00:04<00:10, 16.95it/s]
# CACHE HIT...:  29%|██▉       | 74/251 [00:04<00:10, 17.53it/s]
# CACHE HIT...:  30%|███       | 76/251 [00:04<00:09, 17.78it/s]
# CACHE HIT...:  31%|███▏      | 79/251 [00:04<00:09, 18.28it/s]
# CACHE HIT...:  32%|███▏      | 81/251 [00:04<00:09, 18.11it/s]
# CACHE HIT...:  33%|███▎      | 83/251 [00:04<00:09, 17.60it/s]
# CACHE HIT...:  34%|███▍      | 86/251 [00:04<00:08, 18.52it/s]
# CACHE HIT...:  35%|███▌      | 88/251 [00:05<00:08, 18.60it/s]
# CACHE HIT...:  36%|███▋      | 91/251 [00:05<00:08, 19.19it/s]
# CACHE HIT...:  37%|███▋      | 93/251 [00:05<00:08, 19.32it/s]
# CACHE HIT...:  38%|███▊      | 96/251 [00:05<00:07, 20.18it/s]
# CACHE HIT...:  39%|███▉      | 99/251 [00:05<00:07, 19.17it/s]
# CACHE HIT...:  40%|████      | 101/251 [00:05<00:08, 18.17it/s]
# CACHE HIT...:  41%|████      | 103/251 [00:05<00:08, 17.83it/s]
# CACHE HIT...:  42%|████▏     | 105/251 [00:06<00:08, 16.67it/s]
# CACHE HIT...:  43%|████▎     | 107/251 [00:06<00:08, 16.05it/s]
# CACHE HIT...:  43%|████▎     | 109/251 [00:06<00:08, 16.47it/s]
# CACHE HIT...:  44%|████▍     | 111/251 [00:06<00:08, 15.92it/s]
# CACHE HIT...:  45%|████▌     | 113/251 [00:06<00:08, 16.50it/s]
# CACHE HIT...:  46%|████▌     | 115/251 [00:06<00:07, 17.03it/s]
# CACHE HIT...:  47%|████▋     | 117/251 [00:06<00:08, 16.21it/s]
# CACHE HIT...:  47%|████▋     | 119/251 [00:06<00:07, 16.95it/s]
# CACHE HIT...:  48%|████▊     | 121/251 [00:07<00:08, 16.14it/s]
# CACHE HIT...:  49%|████▉     | 123/251 [00:07<00:07, 16.80it/s]
# CACHE HIT...:  50%|████▉     | 125/251 [00:07<00:07, 16.84it/s]
# CACHE HIT...:  51%|█████     | 127/251 [00:07<00:07, 16.24it/s]
# CACHE HIT...:  51%|█████▏    | 129/251 [00:07<00:07, 16.17it/s]
# CACHE HIT...:  52%|█████▏    | 131/251 [00:07<00:07, 15.84it/s]
# CACHE HIT...:  53%|█████▎    | 133/251 [00:07<00:07, 16.47it/s]
# CACHE HIT...:  54%|█████▍    | 135/251 [00:07<00:07, 16.01it/s]
# CACHE HIT...:  55%|█████▍    | 137/251 [00:07<00:06, 16.51it/s]
# CACHE HIT...:  55%|█████▌    | 139/251 [00:08<00:06, 16.71it/s]
# CACHE HIT...:  56%|█████▌    | 141/251 [00:08<00:06, 16.86it/s]
# CACHE HIT...:  57%|█████▋    | 143/251 [00:08<00:06, 17.26it/s]
# CACHE HIT...:  58%|█████▊    | 145/251 [00:08<00:06, 17.40it/s]
# CACHE HIT...:  59%|█████▊    | 147/251 [00:08<00:05, 17.86it/s]
# CACHE HIT...:  59%|█████▉    | 149/251 [00:08<00:05, 18.11it/s]
# CACHE HIT...:  60%|██████    | 151/251 [00:08<00:05, 17.93it/s]
# CACHE HIT...:  61%|██████    | 153/251 [00:08<00:05, 17.66it/s]
# CACHE HIT...:  62%|██████▏   | 155/251 [00:09<00:05, 16.97it/s]
# CACHE HIT...:  63%|██████▎   | 157/251 [00:09<00:05, 17.18it/s]
# CACHE HIT...:  63%|██████▎   | 159/251 [00:09<00:05, 16.30it/s]
# CACHE HIT...:  64%|██████▍   | 161/251 [00:09<00:05, 16.90it/s]
# CACHE HIT...:  65%|██████▍   | 163/251 [00:09<00:05, 15.88it/s]
# CACHE HIT...:  66%|██████▌   | 165/251 [00:09<00:05, 16.12it/s]
# CACHE HIT...:  67%|██████▋   | 167/251 [00:09<00:05, 15.73it/s]
# CACHE HIT...:  67%|██████▋   | 169/251 [00:09<00:05, 15.07it/s]
# CACHE HIT...:  68%|██████▊   | 171/251 [00:10<00:05, 15.66it/s]
# CACHE HIT...:  69%|██████▉   | 173/251 [00:10<00:05, 15.04it/s]
# CACHE HIT...:  70%|██████▉   | 175/251 [00:10<00:04, 15.84it/s]
# CACHE HIT...:  71%|███████   | 178/251 [00:10<00:04, 18.09it/s]
# CACHE HIT...:  72%|███████▏  | 181/251 [00:10<00:03, 20.61it/s]
# CACHE HIT...:  73%|███████▎  | 184/251 [00:10<00:03, 21.21it/s]
# CACHE HIT...:  75%|███████▍  | 187/251 [00:10<00:03, 17.41it/s]
# CACHE HIT...:  75%|███████▌  | 189/251 [00:10<00:03, 17.55it/s]
# CACHE HIT...:  76%|███████▌  | 191/251 [00:11<00:03, 16.69it/s]
# CACHE HIT...:  77%|███████▋  | 193/251 [00:11<00:03, 16.63it/s]
# CACHE HIT...:  78%|███████▊  | 195/251 [00:11<00:03, 15.60it/s]
# CACHE HIT...:  78%|███████▊  | 197/251 [00:11<00:03, 15.77it/s]
# CACHE HIT...:  79%|███████▉  | 199/251 [00:11<00:03, 15.97it/s]
# CACHE HIT...:  80%|████████  | 201/251 [00:11<00:03, 15.81it/s]
# CACHE HIT...:  81%|████████  | 203/251 [00:11<00:02, 16.08it/s]
# CACHE HIT...:  82%|████████▏ | 205/251 [00:12<00:02, 15.62it/s]
# CACHE HIT...:  82%|████████▏ | 207/251 [00:12<00:02, 15.99it/s]
# CACHE HIT...:  83%|████████▎ | 209/251 [00:12<00:02, 15.67it/s]
# CACHE HIT...:  84%|████████▍ | 211/251 [00:12<00:02, 15.59it/s]
# CACHE HIT...:  85%|████████▍ | 213/251 [00:12<00:02, 15.75it/s]
# CACHE HIT...:  86%|████████▌ | 215/251 [00:12<00:02, 16.25it/s]
# CACHE HIT...:  86%|████████▋ | 217/251 [00:12<00:02, 16.94it/s]
# CACHE HIT...:  87%|████████▋ | 219/251 [00:12<00:01, 16.24it/s]
# CACHE HIT...:  88%|████████▊ | 221/251 [00:13<00:01, 16.17it/s]
# CACHE HIT...:  89%|████████▉ | 223/251 [00:13<00:01, 15.22it/s]
# CACHE HIT...:  90%|████████▉ | 225/251 [00:13<00:01, 14.46it/s]
# CACHE HIT...:  90%|█████████ | 227/251 [00:13<00:01, 14.20it/s]
# CACHE HIT...:  91%|█████████ | 229/251 [00:13<00:01, 13.86it/s]
# CACHE HIT...:  92%|█████████▏| 231/251 [00:13<00:01, 13.66it/s]
# CACHE HIT...:  93%|█████████▎| 233/251 [00:13<00:01, 13.26it/s]
# CACHE HIT...:  94%|█████████▎| 235/251 [00:14<00:01, 13.32it/s]
# CACHE HIT...:  94%|█████████▍| 237/251 [00:14<00:01, 13.94it/s]
# CACHE HIT...:  95%|█████████▌| 239/251 [00:14<00:00, 13.38it/s]
# CACHE HIT...:  96%|█████████▌| 241/251 [00:14<00:00, 12.99it/s]
# CACHE HIT...:  97%|█████████▋| 243/251 [00:14<00:00, 13.22it/s]
# CACHE HIT...:  98%|█████████▊| 245/251 [00:14<00:00, 13.80it/s]
# CACHE HIT...:  99%|█████████▉| 248/251 [00:14<00:00, 16.80it/s]
# CACHE HIT...: 100%|█████████▉| 250/251 [00:15<00:00, 15.81it/s]
# CACHE HIT...: 100%|██████████| 251/251 [00:15<00:00, 16.57it/s]
# MERGING SLICES...:   0%|          | 0/251 [00:00<?, ?it/s]
# MERGING SLICES...:   1%|          | 2/251 [00:00<00:16, 14.76it/s]
# MERGING SLICES...:   2%|▏         | 4/251 [00:00<00:19, 12.54it/s]
# MERGING SLICES...:   2%|▏         | 6/251 [00:00<00:24, 10.00it/s]
# MERGING SLICES...:   3%|▎         | 8/251 [00:00<00:22, 10.83it/s]
# MERGING SLICES...:   4%|▍         | 10/251 [00:01<00:26,  9.13it/s]
# MERGING SLICES...:   4%|▍         | 11/251 [00:01<00:31,  7.63it/s]
# MERGING SLICES...:   5%|▍         | 12/251 [00:01<00:35,  6.82it/s]
# MERGING SLICES...:   5%|▌         | 13/251 [00:01<00:39,  6.05it/s]
# MERGING SLICES...:   6%|▌         | 14/251 [00:01<00:41,  5.69it/s]
# MERGING SLICES...:   6%|▌         | 15/251 [00:02<00:44,  5.36it/s]
# MERGING SLICES...:   6%|▋         | 16/251 [00:02<00:45,  5.12it/s]
# MERGING SLICES...:   7%|▋         | 17/251 [00:02<00:51,  4.56it/s]
# MERGING SLICES...:   7%|▋         | 18/251 [00:02<00:53,  4.32it/s]
# MERGING SLICES...:   8%|▊         | 19/251 [00:03<00:57,  4.01it/s]
# MERGING SLICES...:   8%|▊         | 20/251 [00:03<01:04,  3.59it/s]
# MERGING SLICES...:   8%|▊         | 21/251 [00:03<01:13,  3.14it/s]
# MERGING SLICES...:   9%|▉         | 22/251 [00:04<01:21,  2.82it/s]
# MERGING SLICES...:   9%|▉         | 23/251 [00:04<01:24,  2.69it/s]
# MERGING SLICES...:  10%|▉         | 24/251 [00:05<01:34,  2.40it/s]
# MERGING SLICES...:  10%|▉         | 25/251 [00:05<01:36,  2.33it/s]
# MERGING SLICES...:  10%|█         | 26/251 [00:06<01:35,  2.36it/s]
# MERGING SLICES...:  11%|█         | 27/251 [00:06<01:32,  2.41it/s]
# MERGING SLICES...:  11%|█         | 28/251 [00:06<01:32,  2.40it/s]
# MERGING SLICES...:  12%|█▏        | 29/251 [00:07<01:36,  2.30it/s]
# MERGING SLICES...:  12%|█▏        | 30/251 [00:07<01:39,  2.22it/s]
# MERGING SLICES...:  12%|█▏        | 31/251 [00:08<01:42,  2.15it/s]
# MERGING SLICES...:  13%|█▎        | 32/251 [00:08<01:50,  1.98it/s]
# MERGING SLICES...:  13%|█▎        | 33/251 [00:09<01:54,  1.90it/s]
# MERGING SLICES...:  14%|█▎        | 34/251 [00:10<01:56,  1.87it/s]
# MERGING SLICES...:  14%|█▍        | 35/251 [00:10<01:59,  1.80it/s]
# MERGING SLICES...:  14%|█▍        | 36/251 [00:11<02:04,  1.73it/s]
# MERGING SLICES...:  15%|█▍        | 37/251 [00:11<02:05,  1.71it/s]
# MERGING SLICES...:  15%|█▌        | 38/251 [00:12<02:13,  1.60it/s]
# MERGING SLICES...:  16%|█▌        | 39/251 [00:13<02:22,  1.49it/s]
# MERGING SLICES...:  16%|█▌        | 40/251 [00:14<02:24,  1.46it/s]
# MERGING SLICES...:  16%|█▋        | 41/251 [00:14<02:25,  1.44it/s]
# MERGING SLICES...:  17%|█▋        | 42/251 [00:15<02:26,  1.43it/s]
# MERGING SLICES...:  17%|█▋        | 43/251 [00:16<02:27,  1.41it/s]
# MERGING SLICES...:  18%|█▊        | 44/251 [00:17<02:30,  1.37it/s]
# MERGING SLICES...:  18%|█▊        | 45/251 [00:17<02:33,  1.34it/s]
# MERGING SLICES...:  18%|█▊        | 46/251 [00:18<02:38,  1.29it/s]
# MERGING SLICES...:  19%|█▊        | 47/251 [00:19<02:40,  1.27it/s]
# MERGING SLICES...:  19%|█▉        | 48/251 [00:20<02:41,  1.26it/s]
# MERGING SLICES...:  20%|█▉        | 49/251 [00:20<02:27,  1.37it/s]
# MERGING SLICES...:  20%|█▉        | 50/251 [00:21<02:21,  1.42it/s]
# MERGING SLICES...:  20%|██        | 51/251 [00:22<02:13,  1.50it/s]
# MERGING SLICES...:  21%|██        | 52/251 [00:22<02:12,  1.50it/s]
# MERGING SLICES...:  21%|██        | 53/251 [00:23<02:13,  1.49it/s]
# MERGING SLICES...:  22%|██▏       | 54/251 [00:24<02:15,  1.46it/s]
# MERGING SLICES...:  22%|██▏       | 55/251 [00:24<02:14,  1.46it/s]
# MERGING SLICES...:  22%|██▏       | 56/251 [00:25<02:17,  1.42it/s]
# MERGING SLICES...:  23%|██▎       | 57/251 [00:26<02:19,  1.39it/s]
# MERGING SLICES...:  23%|██▎       | 58/251 [00:27<02:24,  1.34it/s]
# MERGING SLICES...:  24%|██▎       | 59/251 [00:28<02:27,  1.30it/s]
# MERGING SLICES...:  24%|██▍       | 60/251 [00:28<02:34,  1.23it/s]
# MERGING SLICES...:  24%|██▍       | 61/251 [00:29<02:36,  1.21it/s]
# MERGING SLICES...:  25%|██▍       | 62/251 [00:30<02:37,  1.20it/s]
# MERGING SLICES...:  25%|██▌       | 63/251 [00:31<02:38,  1.18it/s]
# MERGING SLICES...:  25%|██▌       | 64/251 [00:32<02:39,  1.17it/s]
# MERGING SLICES...:  26%|██▌       | 65/251 [00:33<02:40,  1.16it/s]
# MERGING SLICES...:  26%|██▋       | 66/251 [00:34<02:42,  1.14it/s]
# MERGING SLICES...:  27%|██▋       | 67/251 [00:35<02:48,  1.09it/s]
# MERGING SLICES...:  27%|██▋       | 68/251 [00:36<02:52,  1.06it/s]
# MERGING SLICES...:  27%|██▋       | 69/251 [00:37<02:59,  1.01it/s]
# MERGING SLICES...:  28%|██▊       | 70/251 [00:38<02:57,  1.02it/s]
# MERGING SLICES...:  28%|██▊       | 71/251 [00:39<03:05,  1.03s/it]
# MERGING SLICES...:  29%|██▊       | 72/251 [00:40<03:08,  1.05s/it]
# MERGING SLICES...:  29%|██▉       | 73/251 [00:41<03:10,  1.07s/it]
# MERGING SLICES...:  29%|██▉       | 74/251 [00:42<03:16,  1.11s/it]
# MERGING SLICES...:  30%|██▉       | 75/251 [00:44<03:22,  1.15s/it]
# MERGING SLICES...:  30%|███       | 76/251 [00:45<03:40,  1.26s/it]
# MERGING SLICES...:  31%|███       | 77/251 [00:47<03:49,  1.32s/it]
# MERGING SLICES...:  31%|███       | 78/251 [00:48<03:53,  1.35s/it]
# MERGING SLICES...:  31%|███▏      | 79/251 [00:49<03:58,  1.38s/it]
# MERGING SLICES...:  32%|███▏      | 80/251 [00:51<04:01,  1.41s/it]
# MERGING SLICES...:  32%|███▏      | 81/251 [00:52<04:02,  1.43s/it]
# MERGING SLICES...:  33%|███▎      | 82/251 [00:54<04:03,  1.44s/it]
# MERGING SLICES...:  33%|███▎      | 83/251 [00:55<04:03,  1.45s/it]
# MERGING SLICES...:  33%|███▎      | 84/251 [00:57<04:05,  1.47s/it]
# MERGING SLICES...:  34%|███▍      | 85/251 [00:58<04:07,  1.49s/it]
# MERGING SLICES...:  34%|███▍      | 86/251 [01:00<04:09,  1.51s/it]
# MERGING SLICES...:  35%|███▍      | 87/251 [01:01<04:08,  1.51s/it]
# MERGING SLICES...:  35%|███▌      | 88/251 [01:03<04:07,  1.52s/it]
# MERGING SLICES...:  35%|███▌      | 89/251 [01:05<04:06,  1.52s/it]
# MERGING SLICES...:  36%|███▌      | 90/251 [01:06<04:09,  1.55s/it]
# MERGING SLICES...:  36%|███▋      | 91/251 [01:08<04:11,  1.57s/it]
# MERGING SLICES...:  37%|███▋      | 92/251 [01:09<04:12,  1.59s/it]
# MERGING SLICES...:  37%|███▋      | 93/251 [01:11<04:13,  1.61s/it]
# MERGING SLICES...:  37%|███▋      | 94/251 [01:13<04:14,  1.62s/it]
# MERGING SLICES...:  38%|███▊      | 95/251 [01:14<04:13,  1.62s/it]
# MERGING SLICES...:  38%|███▊      | 96/251 [01:16<04:17,  1.66s/it]
# MERGING SLICES...:  39%|███▊      | 97/251 [01:18<04:19,  1.68s/it]
# MERGING SLICES...:  39%|███▉      | 98/251 [01:20<04:20,  1.70s/it]
# MERGING SLICES...:  39%|███▉      | 99/251 [01:21<04:14,  1.68s/it]
# MERGING SLICES...:  40%|███▉      | 100/251 [01:23<04:16,  1.70s/it]
# MERGING SLICES...:  40%|████      | 101/251 [01:24<03:51,  1.54s/it]
# MERGING SLICES...:  41%|████      | 102/251 [01:25<03:35,  1.45s/it]
# MERGING SLICES...:  41%|████      | 103/251 [01:27<03:28,  1.41s/it]
# MERGING SLICES...:  41%|████▏     | 104/251 [01:28<03:24,  1.39s/it]
# MERGING SLICES...:  42%|████▏     | 105/251 [01:29<03:25,  1.41s/it]
# MERGING SLICES...:  42%|████▏     | 106/251 [01:31<03:25,  1.42s/it]
# MERGING SLICES...:  43%|████▎     | 107/251 [01:32<03:22,  1.40s/it]
# MERGING SLICES...:  43%|████▎     | 108/251 [01:34<03:19,  1.39s/it]
# MERGING SLICES...:  43%|████▎     | 109/251 [01:35<03:17,  1.39s/it]
# MERGING SLICES...:  44%|████▍     | 110/251 [01:36<03:15,  1.39s/it]
# MERGING SLICES...:  44%|████▍     | 111/251 [01:38<03:20,  1.43s/it]
# MERGING SLICES...:  45%|████▍     | 112/251 [01:39<03:22,  1.46s/it]
# MERGING SLICES...:  45%|████▌     | 113/251 [01:41<03:22,  1.47s/it]
# MERGING SLICES...:  45%|████▌     | 114/251 [01:42<03:23,  1.49s/it]
# MERGING SLICES...:  46%|████▌     | 115/251 [01:44<03:28,  1.53s/it]
# MERGING SLICES...:  46%|████▌     | 116/251 [01:46<03:29,  1.55s/it]
# MERGING SLICES...:  47%|████▋     | 117/251 [01:47<03:32,  1.59s/it]
# MERGING SLICES...:  47%|████▋     | 118/251 [01:49<03:39,  1.65s/it]
# MERGING SLICES...:  47%|████▋     | 119/251 [01:51<03:44,  1.70s/it]
# MERGING SLICES...:  48%|████▊     | 120/251 [01:53<03:42,  1.70s/it]
# MERGING SLICES...:  48%|████▊     | 121/251 [01:55<03:45,  1.74s/it]
# MERGING SLICES...:  49%|████▊     | 122/251 [01:56<03:46,  1.75s/it]
# MERGING SLICES...:  49%|████▉     | 123/251 [01:58<03:48,  1.79s/it]
# MERGING SLICES...:  49%|████▉     | 124/251 [02:00<03:52,  1.83s/it]
# MERGING SLICES...:  50%|████▉     | 125/251 [02:02<03:51,  1.84s/it]
# MERGING SLICES...:  50%|█████     | 126/251 [02:04<03:53,  1.87s/it]
# MERGING SLICES...:  51%|█████     | 127/251 [02:06<03:49,  1.85s/it]
# MERGING SLICES...:  51%|█████     | 128/251 [02:08<03:47,  1.85s/it]
# MERGING SLICES...:  51%|█████▏    | 129/251 [02:09<03:48,  1.87s/it]
# MERGING SLICES...:  52%|█████▏    | 130/251 [02:11<03:48,  1.89s/it]
# MERGING SLICES...:  52%|█████▏    | 131/251 [02:13<03:47,  1.90s/it]
# MERGING SLICES...:  53%|█████▎    | 132/251 [02:15<03:46,  1.90s/it]
# MERGING SLICES...:  53%|█████▎    | 133/251 [02:17<03:53,  1.97s/it]
# MERGING SLICES...:  53%|█████▎    | 134/251 [02:20<04:04,  2.09s/it]
# MERGING SLICES...:  54%|█████▍    | 135/251 [02:22<04:04,  2.11s/it]
# MERGING SLICES...:  54%|█████▍    | 136/251 [02:24<04:07,  2.15s/it]
# MERGING SLICES...:  55%|█████▍    | 137/251 [02:26<04:05,  2.15s/it]
# MERGING SLICES...:  55%|█████▍    | 138/251 [02:28<04:02,  2.15s/it]
# MERGING SLICES...:  55%|█████▌    | 139/251 [02:30<03:54,  2.10s/it]
# MERGING SLICES...:  56%|█████▌    | 140/251 [02:33<03:53,  2.11s/it]
# MERGING SLICES...:  56%|█████▌    | 141/251 [02:35<03:54,  2.13s/it]
# MERGING SLICES...:  57%|█████▋    | 142/251 [02:37<03:56,  2.17s/it]
# MERGING SLICES...:  57%|█████▋    | 143/251 [02:39<03:55,  2.18s/it]
# MERGING SLICES...:  57%|█████▋    | 144/251 [02:41<03:56,  2.21s/it]
# MERGING SLICES...:  58%|█████▊    | 145/251 [02:44<03:56,  2.23s/it]
# MERGING SLICES...:  58%|█████▊    | 146/251 [02:46<03:54,  2.24s/it]
# MERGING SLICES...:  59%|█████▊    | 147/251 [02:48<03:55,  2.27s/it]
# MERGING SLICES...:  59%|█████▉    | 148/251 [02:51<03:57,  2.30s/it]
# MERGING SLICES...:  59%|█████▉    | 149/251 [02:53<03:59,  2.34s/it]
# MERGING SLICES...:  60%|█████▉    | 150/251 [02:56<04:16,  2.54s/it]
# MERGING SLICES...:  60%|██████    | 151/251 [02:59<04:28,  2.69s/it]
# MERGING SLICES...:  61%|██████    | 152/251 [03:02<04:34,  2.78s/it]
# MERGING SLICES...:  61%|██████    | 153/251 [03:05<04:36,  2.82s/it]
# MERGING SLICES...:  61%|██████▏   | 154/251 [03:08<04:41,  2.90s/it]
# MERGING SLICES...:  62%|██████▏   | 155/251 [03:11<04:42,  2.94s/it]
# MERGING SLICES...:  62%|██████▏   | 156/251 [03:14<04:39,  2.95s/it]
# MERGING SLICES...:  63%|██████▎   | 157/251 [03:17<04:39,  2.98s/it]
# MERGING SLICES...:  63%|██████▎   | 158/251 [03:20<04:41,  3.03s/it]
# MERGING SLICES...:  63%|██████▎   | 159/251 [03:23<04:41,  3.06s/it]
# MERGING SLICES...:  64%|██████▎   | 160/251 [03:27<04:39,  3.07s/it]
# MERGING SLICES...:  64%|██████▍   | 161/251 [03:30<04:37,  3.09s/it]
# MERGING SLICES...:  65%|██████▍   | 162/251 [03:33<04:42,  3.17s/it]
# MERGING SLICES...:  65%|██████▍   | 163/251 [03:36<04:41,  3.20s/it]
# MERGING SLICES...:  65%|██████▌   | 164/251 [03:39<04:31,  3.12s/it]
# MERGING SLICES...:  66%|██████▌   | 165/251 [03:43<04:32,  3.17s/it]
# MERGING SLICES...:  66%|██████▌   | 166/251 [03:46<04:31,  3.19s/it]
# MERGING SLICES...:  67%|██████▋   | 167/251 [03:49<04:39,  3.32s/it]
# MERGING SLICES...:  67%|██████▋   | 168/251 [03:53<04:34,  3.30s/it]
# MERGING SLICES...:  67%|██████▋   | 169/251 [03:56<04:30,  3.30s/it]
# MERGING SLICES...:  68%|██████▊   | 170/251 [03:59<04:25,  3.27s/it]
# MERGING SLICES...:  68%|██████▊   | 171/251 [04:03<04:23,  3.30s/it]
# MERGING SLICES...:  69%|██████▊   | 172/251 [04:06<04:23,  3.34s/it]
# MERGING SLICES...:  69%|██████▉   | 173/251 [04:10<04:24,  3.40s/it]
# MERGING SLICES...:  69%|██████▉   | 174/251 [04:13<04:23,  3.42s/it]
# MERGING SLICES...:  70%|██████▉   | 175/251 [04:17<04:21,  3.44s/it]
# MERGING SLICES...:  70%|███████   | 176/251 [04:20<04:28,  3.58s/it]
# MERGING SLICES...:  71%|███████   | 177/251 [04:24<04:22,  3.55s/it]
# MERGING SLICES...:  71%|███████   | 178/251 [04:27<04:14,  3.48s/it]
# MERGING SLICES...:  71%|███████▏  | 179/251 [04:31<04:11,  3.49s/it]
# MERGING SLICES...:  72%|███████▏  | 180/251 [04:34<04:05,  3.46s/it]
# MERGING SLICES...:  72%|███████▏  | 181/251 [04:38<04:01,  3.45s/it]
# MERGING SLICES...:  73%|███████▎  | 182/251 [04:41<03:58,  3.46s/it]
# MERGING SLICES...:  73%|███████▎  | 183/251 [04:45<04:04,  3.59s/it]
# MERGING SLICES...:  73%|███████▎  | 184/251 [04:48<03:52,  3.47s/it]
# MERGING SLICES...:  74%|███████▎  | 185/251 [04:52<03:51,  3.50s/it]
# MERGING SLICES...:  74%|███████▍  | 186/251 [04:55<03:47,  3.51s/it]
# MERGING SLICES...:  75%|███████▍  | 187/251 [04:59<03:45,  3.52s/it]
# MERGING SLICES...:  75%|███████▍  | 188/251 [05:02<03:42,  3.53s/it]
# MERGING SLICES...:  75%|███████▌  | 189/251 [05:06<03:39,  3.54s/it]
# MERGING SLICES...:  76%|███████▌  | 190/251 [05:10<03:39,  3.60s/it]
# MERGING SLICES...:  76%|███████▌  | 191/251 [05:14<03:42,  3.70s/it]
# MERGING SLICES...:  76%|███████▋  | 192/251 [05:18<03:45,  3.82s/it]
# MERGING SLICES...:  77%|███████▋  | 193/251 [05:20<03:17,  3.40s/it]
# MERGING SLICES...:  77%|███████▋  | 194/251 [05:23<03:01,  3.19s/it]
# MERGING SLICES...:  78%|███████▊  | 195/251 [05:25<02:49,  3.03s/it]
# MERGING SLICES...:  78%|███████▊  | 196/251 [05:28<02:41,  2.93s/it]
# MERGING SLICES...:  78%|███████▊  | 197/251 [05:31<02:34,  2.85s/it]
# MERGING SLICES...:  79%|███████▉  | 198/251 [05:33<02:27,  2.78s/it]
# MERGING SLICES...:  79%|███████▉  | 199/251 [05:36<02:24,  2.77s/it]
# MERGING SLICES...:  80%|███████▉  | 200/251 [05:39<02:21,  2.78s/it]
# MERGING SLICES...:  80%|████████  | 201/251 [05:42<02:20,  2.81s/it]
# MERGING SLICES...:  80%|████████  | 202/251 [05:45<02:21,  2.88s/it]
# MERGING SLICES...:  81%|████████  | 203/251 [05:48<02:18,  2.88s/it]
# MERGING SLICES...:  81%|████████▏ | 204/251 [05:50<02:11,  2.80s/it]
# MERGING SLICES...:  82%|████████▏ | 205/251 [05:53<02:08,  2.79s/it]
# MERGING SLICES...:  82%|████████▏ | 206/251 [05:56<02:03,  2.75s/it]
# MERGING SLICES...:  82%|████████▏ | 207/251 [05:59<02:00,  2.75s/it]
# MERGING SLICES...:  83%|████████▎ | 208/251 [06:01<01:58,  2.75s/it]
# MERGING SLICES...:  83%|████████▎ | 209/251 [06:04<01:55,  2.75s/it]
# MERGING SLICES...:  84%|████████▎ | 210/251 [06:07<01:53,  2.76s/it]
# MERGING SLICES...:  84%|████████▍ | 211/251 [06:10<01:51,  2.79s/it]
# MERGING SLICES...:  84%|████████▍ | 212/251 [06:13<01:49,  2.80s/it]
# MERGING SLICES...:  85%|████████▍ | 213/251 [06:16<01:48,  2.86s/it]
# MERGING SLICES...:  85%|████████▌ | 214/251 [06:19<01:49,  2.96s/it]
# MERGING SLICES...:  86%|████████▌ | 215/251 [06:22<01:47,  2.98s/it]
# MERGING SLICES...:  86%|████████▌ | 216/251 [06:25<01:43,  2.96s/it]
# MERGING SLICES...:  86%|████████▋ | 217/251 [06:28<01:41,  2.99s/it]
# MERGING SLICES...:  87%|████████▋ | 218/251 [06:31<01:39,  3.03s/it]
# MERGING SLICES...:  87%|████████▋ | 219/251 [06:34<01:37,  3.04s/it]
# MERGING SLICES...:  88%|████████▊ | 220/251 [06:37<01:35,  3.07s/it]
# MERGING SLICES...:  88%|████████▊ | 221/251 [06:40<01:33,  3.11s/it]
# MERGING SLICES...:  88%|████████▊ | 222/251 [06:43<01:30,  3.12s/it]
# MERGING SLICES...:  89%|████████▉ | 223/251 [06:47<01:28,  3.16s/it]
# MERGING SLICES...:  89%|████████▉ | 224/251 [06:50<01:28,  3.27s/it]
# MERGING SLICES...:  90%|████████▉ | 225/251 [06:54<01:26,  3.34s/it]
# MERGING SLICES...:  90%|█████████ | 226/251 [06:57<01:23,  3.33s/it]
# MERGING SLICES...:  90%|█████████ | 227/251 [07:00<01:20,  3.36s/it]
# MERGING SLICES...:  91%|█████████ | 228/251 [07:04<01:16,  3.35s/it]
# MERGING SLICES...:  91%|█████████ | 229/251 [07:07<01:15,  3.42s/it]
# MERGING SLICES...:  92%|█████████▏| 230/251 [07:11<01:12,  3.45s/it]
# MERGING SLICES...:  92%|█████████▏| 231/251 [07:14<01:09,  3.49s/it]
# MERGING SLICES...:  92%|█████████▏| 232/251 [07:18<01:06,  3.50s/it]
# MERGING SLICES...:  93%|█████████▎| 233/251 [07:22<01:04,  3.59s/it]
# MERGING SLICES...:  93%|█████████▎| 234/251 [07:26<01:02,  3.66s/it]
# MERGING SLICES...:  94%|█████████▎| 235/251 [07:29<00:58,  3.67s/it]
# MERGING SLICES...:  94%|█████████▍| 236/251 [07:33<00:54,  3.63s/it]
# MERGING SLICES...:  94%|█████████▍| 237/251 [07:36<00:51,  3.66s/it]
# MERGING SLICES...:  95%|█████████▍| 238/251 [07:40<00:48,  3.69s/it]
# MERGING SLICES...:  95%|█████████▌| 239/251 [07:44<00:44,  3.73s/it]
# MERGING SLICES...:  96%|█████████▌| 240/251 [07:48<00:41,  3.78s/it]
# MERGING SLICES...:  96%|█████████▌| 241/251 [07:52<00:38,  3.81s/it]
# MERGING SLICES...:  96%|█████████▋| 242/251 [07:56<00:34,  3.86s/it]
# MERGING SLICES...:  97%|█████████▋| 243/251 [08:00<00:31,  3.97s/it]
# MERGING SLICES...:  97%|█████████▋| 244/251 [08:04<00:27,  3.98s/it]
# MERGING SLICES...:  98%|█████████▊| 245/251 [08:08<00:24,  4.00s/it]
# MERGING SLICES...:  98%|█████████▊| 246/251 [08:12<00:19,  3.96s/it]
# MERGING SLICES...:  98%|█████████▊| 247/251 [08:16<00:15,  3.96s/it]
# MERGING SLICES...:  99%|█████████▉| 248/251 [08:20<00:12,  4.00s/it]
# MERGING SLICES...:  99%|█████████▉| 249/251 [08:24<00:08,  4.01s/it]
# MERGING SLICES...: 100%|█████████▉| 250/251 [08:28<00:04,  4.04s/it]
# MERGING SLICES...: 100%|██████████| 251/251 [08:32<00:00,  4.09s/it]
# MERGING SLICES...: 100%|██████████| 251/251 [08:32<00:00,  2.04s/it]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = sdr.load_usd_swaps(START, END, cache_path=CACHE_PATH)
#       2 print(f"Loaded {len(df):,} classified trades from {df['execution_date'].nunique()} trading days")
#       3 print(f"Total DV01: {sdr.format_dv01(df['dv01'].sum())}")
#
# File ~\clee\ARBS\notebooks\sdr\_usd_swaps_common.py:151, in load_usd_swaps(start, end, cache_path, curve_source, detect_packages)
#     134 """
#     135 Load and classify SDR trades for a date range.
#     136
#    (...)    148     is_spreadover, is_asset_swap
#     149 """
#     150 product = USD_SwapProduct()
# --> 151 df = product.build_classification_dataframe(
#     152     start=start,
#     153     end=end,
#     154     cache_path=cache_path,
#     155     detect_curve=detect_packages,
#     156     detect_fly=detect_packages,
#     157     detect_mms=detect_packages,
#     158     detect_invoice=detect_packages,
#     159     detect_mac=detect_packages,
#     160     detect_spreadover=detect_packages,
#     161     curve_source=curve_source,
#     162 )
#     164 if df.empty:
#     165     return df
#
# File ~\clee\ARBS\SDRUtils\products\usd\usd_swaps.py:697, in USD_SwapProduct.build_classification_dataframe(self, start, end, cache_path, detect_curve, detect_fly, detect_mms, detect_invoice, detect_mac, detect_spreadover, ignore_cache, merge_package_legs, use_v2_classification, **kwargs)
#     680 def build_classification_dataframe(
#     681     self,
#     682     start: datetime.datetime,
#    (...)    694     **kwargs: Any,
#     695 ):
#     696     sdr = SDRDataBuilder(cache_path=cache_path, show_tqdm=True)
# --> 697     raw_sdr_trades_df = sdr.grab_sdr_trades(
#     698         start_timestamp=start,
#     699         end_timestamp=end,
#     700         agency="CFTC",
#     701         asset_class="RATES",
#     702         filter_func=usd_swap_trades,
#     703         ignore_cache=ignore_cache,
#     704     )
#     706     if raw_sdr_trades_df.empty:
#     707         return raw_sdr_trades_df
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1167, in SDRDataBuilder.grab_sdr_trades(self, start_timestamp, end_timestamp, agency, asset_class, ts_col, filter_func, ignore_cache)
#    1164 dfs: List[pd.DataFrame] = []
#    1166 if hist_start_date <= hist_end_date:
# -> 1167     hist_df = self.grab_historical_sdr_trades(
#    1168         start_date=hist_start_date,
#    1169         end_date=hist_end_date,
#    1170         agency=agency,
#    1171         asset_class=asset_class,
#    1172         one_df=True,
#    1173         ignore_cache=ignore_cache,
#    1174     )
#    1175     if not hist_df.empty:
#    1176         mask = (hist_df[ts_col] >= start_ts) & (hist_df[ts_col] <= end_ts)
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:1133, in SDRDataBuilder.grab_historical_sdr_trades(self, start_date, end_date, agency, asset_class, one_df, ignore_cache)
#    1130         merged[day] = day_df.assign(file_date=day)
#    1132 if one_df:
# -> 1133     return _concat_dfs(
#    1134         merged.values(),
#    1135         use_polars=True,
#    1136         show_tqdm=self._show_tqdm,
#    1137         tqdm_desc="MERGING SLICES...",
#    1138         unique_subset=["Dissemination Identifier"],
#    1139         sort_by="Event timestamp",
#    1140         chunk_size=1000,
#    1141     )
#    1143 return merged
#
# File ~\clee\ARBS\SDRUtils\data\builder.py:913, in _concat_dfs(frames, unique_subset, sort_by, use_polars, show_tqdm, tqdm_desc, chunk_size, filter_func)
#     910 if not kept:
#     911     return pd.DataFrame()
# --> 913 out = kept[0] if len(kept) == 1 else pd.concat(kept, ignore_index=True, copy=False)
#     915 # No need to drop_duplicates again for single-key path (already enforced)
#     916 if sort_by and sort_by in out.columns:
#
# File ~\anaconda3\envs\stir\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~\anaconda3\envs\stir\Lib\site-packages\pandas\core\reshape\concat.py:688, in _Concatenator.get_result(self)
#     684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
# --> 688     new_data._consolidate_inplace()
#     690 out = sample._constructor_from_mgr(new_data, axes=new_data.axes)
#     691 return out.__finalize__(self, method="concat")
#
# File ~\anaconda3\envs\stir\Lib\site-packages\pandas\core\internals\managers.py:1788, in BlockManager._consolidate_inplace(self)
#    1782 def _consolidate_inplace(self) -> None:
#    1783     # In general, _consolidate_inplace should only be called via
#    1784     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1785     #  the DataFrame's _item_cache. The exception is for newly-created
#    1786     #  BlockManager objects not yet attached to a DataFrame.
#    1787     if not self.is_consolidated():
# -> 1788         self.blocks = _consolidate(self.blocks)
#    1789         self._is_consolidated = True
#    1790         self._known_consolidated = True
#
# File ~\anaconda3\envs\stir\Lib\site-packages\pandas\core\internals\managers.py:2269, in _consolidate(blocks)
#    2267 new_blocks: list[Block] = []
#    2268 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2269     merged_blocks, _ = _merge_blocks(
#    2270         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2271     )
#    2272     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2273 return tuple(new_blocks)
#
# File ~\anaconda3\envs\stir\Lib\site-packages\pandas\core\internals\managers.py:2294, in _merge_blocks(blocks, dtype, can_consolidate)
#    2287 new_values: ArrayLike
#    2289 if isinstance(blocks[0].dtype, np.dtype):
#    2290     # error: List comprehension has incompatible type List[Union[ndarray,
#    2291     # ExtensionArray]]; expected List[Union[complex, generic,
#    2292     # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2293     # Sequence[Sequence[Any]], SupportsArray]]
# -> 2294     new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2295 else:
#    2296     bvals = [blk.values for blk in blocks]
#
# File ~\anaconda3\envs\stir\Lib\site-packages\numpy\_core\shape_base.py:292, in vstack(tup, dtype, casting)
#     290 if not isinstance(arrs, tuple):
#     291     arrs = (arrs,)
# --> 292 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# MemoryError: Unable to allocate 4.10 GiB for an array with shape (95, 5791031) and data type object

# %% [markdown]
# ## 1. Trade Type Breakdown (DV01)
# Decompose raw SDR trades into economic form: outrights, curves, flies, spreadovers, MAC, IMM, FOMC.
# ~25% of SDR trades are packages — raw data misleads without decomposition.

# %%
# Assign effective trade type for visualization
def assign_trade_type(row):
    pkg = str(row.get("package_type", "")).upper()
    if pkg in ("CURVE", "FLY"):
        return pkg
    if row.get("is_spreadover", False):
        return "SPREADOVER"
    st = str(row.get("special_tenor_type", "STANDARD")).upper()
    if st in ("MAC", "IMM", "FOMC", "MATCHED_MATURITY", "INVOICE_SWAP"):
        return st
    return "OUTRIGHT"

df["trade_type"] = df.apply(assign_trade_type, axis=1)

pivot = sdr.daily_dv01_by_group(df, "trade_type")
type_order = ["OUTRIGHT", "CURVE", "FLY", "SPREADOVER", "MAC", "IMM", "FOMC", "MATCHED_MATURITY", "INVOICE_SWAP"]
pivot = pivot[[c for c in type_order if c in pivot.columns]]

sdr.plot_stacked_bar(pivot, "Daily DV01 by Trade Type", color_map=sdr.PACKAGE_COLORS)
plt.show()

# Summary stats
print("\nTrade Type Summary:")
type_summary = df.groupby("trade_type").agg(
    count=("dv01", "size"),
    total_dv01=("dv01", "sum"),
    pct_count=("dv01", "size"),
).assign(
    pct_count=lambda x: x["count"] / x["count"].sum() * 100,
    pct_dv01=lambda x: x["total_dv01"] / x["total_dv01"].sum() * 100,
)
print(type_summary.round(1).to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      10         return st
#      11     return "OUTRIGHT"
# ---> 13 df["trade_type"] = df.apply(assign_trade_type, axis=1)
#      15 pivot = sdr.daily_dv01_by_group(df, "trade_type")
#      16 type_order = ["OUTRIGHT", "CURVE", "FLY", "SPREADOVER", "MAC", "IMM", "FOMC", "MATCHED_MATURITY", "INVOICE_SWAP"]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 2. Package Decomposition Table
# For each detected package (curve, fly): show leg tenors, net DV01, and execution timestamp.

# %%
packages = sdr.filter_packages(df)
if not packages.empty:
    pkg_summary = packages.groupby("package_id").agg(
        package_type=("package_type", "first"),
        num_legs=("trade_id", "size"),
        tenors=("tenor_label", lambda x: " / ".join(sorted(x.unique()))),
        net_dv01=("dv01", "sum"),
        execution_time=("execution_timestamp", "first"),
    ).sort_values("net_dv01", ascending=False)
    
    print(f"Detected {len(pkg_summary)} packages ({len(packages)} legs)")
    print(f"  Curves: {(pkg_summary['package_type'] == 'CURVE').sum()}")
    print(f"  Flies: {(pkg_summary['package_type'] == 'FLY').sum()}")
    print(f"\nTop 20 packages by DV01:")
    display(pkg_summary.head(20))
else:
    print("No packages detected in this date range.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 packages = sdr.filter_packages(df)
#       2 if not packages.empty:
#       3     pkg_summary = packages.groupby("package_id").agg(
#       4         package_type=("package_type", "first"),
#       5         num_legs=("trade_id", "size"),
#    (...)      8         execution_time=("execution_timestamp", "first"),
#       9     ).sort_values("net_dv01", ascending=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Rate Index Split
# SOFR OIS vs FedFunds OIS vs Basis. Volume distribution by underlying rate index.

# %%
if "rate_index" in df.columns:
    ri_pivot = sdr.daily_dv01_by_group(df, "rate_index")
    sdr.plot_stacked_area(ri_pivot, "Daily DV01 by Rate Index", color_map=sdr.RATE_INDEX_COLORS)
    plt.show()

    # Pie chart
    ri_totals = df.groupby("rate_index")["dv01"].sum()
    fig, ax = plt.subplots(figsize=(8, 8))
    colors = [sdr.RATE_INDEX_COLORS.get(ri, "#999") for ri in ri_totals.index]
    ri_totals.plot.pie(ax=ax, autopct="%1.1f%%", colors=colors, startangle=90)
    ax.set_ylabel("")
    ax.set_title("DV01 Share by Rate Index")
    plt.tight_layout()
    plt.show()
else:
    print("rate_index column not available — skipping.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 if "rate_index" in df.columns:
#       2     ri_pivot = sdr.daily_dv01_by_group(df, "rate_index")
#       3     sdr.plot_stacked_area(ri_pivot, "Daily DV01 by Rate Index", color_map=sdr.RATE_INDEX_COLORS)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 4. Forward-Start Distribution
# Spot vs forward-starting swap breakdown. ~73% of swaps can be forward-started (per Clarus research).

# %%
fwd_labels = ["spot", "1W", "2W", "1M", "2M", "3M", "6M", "9M", "1Y", "2Y", "3Y+"]

def bucket_forward(label):
    if pd.isna(label) or str(label).lower() == "spot":
        return "spot"
    try:
        years = float(str(label).replace("Y", "").replace("M", ""))
    except ValueError:
        return str(label)
    return str(label) if str(label) in fwd_labels else "3Y+"

df["forward_bucket"] = df["forward_label"].apply(bucket_forward)
fwd_dv01 = df.groupby("forward_bucket")["dv01"].sum()
spot_pct = fwd_dv01.get("spot", 0) / fwd_dv01.sum() * 100

fig, ax = plt.subplots(figsize=(10, 6))
fwd_order = [f for f in fwd_labels if f in fwd_dv01.index]
fwd_dv01[fwd_order].plot.bar(ax=ax, color="#4C78A8", alpha=0.8)
ax.set_title(f"DV01 by Forward Start Period (Spot: {spot_pct:.1f}%)")
ax.set_ylabel("DV01 ($)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9         return str(label)
#      10     return str(label) if str(label) in fwd_labels else "3Y+"
# ---> 12 df["forward_bucket"] = df["forward_label"].apply(bucket_forward)
#      13 fwd_dv01 = df.groupby("forward_bucket")["dv01"].sum()
#      14 spot_pct = fwd_dv01.get("spot", 0) / fwd_dv01.sum() * 100
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 5. Special Tenor Breakdown
# STANDARD / IMM / FOMC / MAC / MATCHED_MATURITY / INVOICE_SWAP classification.

# %%
if "special_tenor_type" in df.columns:
    st_counts = df.groupby("special_tenor_type").agg(
        count=("dv01", "size"),
        total_dv01=("dv01", "sum"),
    )
    st_counts["pct_count"] = st_counts["count"] / st_counts["count"].sum() * 100
    st_counts["pct_dv01"] = st_counts["total_dv01"] / st_counts["total_dv01"].sum() * 100
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    colors = [sdr.SPECIAL_TENOR_COLORS.get(st, "#999") for st in st_counts.index]
    st_counts["count"].plot.bar(ax=axes[0], color=colors, alpha=0.8)
    axes[0].set_title("Trade Count by Special Tenor Type")
    st_counts["total_dv01"].plot.bar(ax=axes[1], color=colors, alpha=0.8)
    axes[1].set_title("DV01 by Special Tenor Type")
    plt.tight_layout()
    plt.show()
    
    print(st_counts.round(1).to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 if "special_tenor_type" in df.columns:
#       2     st_counts = df.groupby("special_tenor_type").agg(
#       3         count=("dv01", "size"),
#       4         total_dv01=("dv01", "sum"),
#       5     )
#       6     st_counts["pct_count"] = st_counts["count"] / st_counts["count"].sum() * 100
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 6. Daily Summary Table
# Per-date rollup: total DV01, trade count, % packages, top 3 tenors by DV01.

# %%
def top_tenors(group, n=3):
    return ", ".join(
        group.groupby("tenor_label")["dv01"]
        .sum()
        .nlargest(n)
        .index.tolist()
    )

daily = df.groupby("execution_date").agg(
    trade_count=("dv01", "size"),
    total_dv01=("dv01", "sum"),
    avg_dv01=("dv01", "mean"),
    pct_packages=("package_type", lambda x: (x.fillna("OUTRIGHT") != "OUTRIGHT").mean() * 100),
    pct_spreadovers=("is_spreadover", lambda x: x.fillna(False).mean() * 100),
    unique_tenors=("tenor_label", "nunique"),
)
daily["top_tenors"] = df.groupby("execution_date").apply(top_tenors)
daily["total_dv01_fmt"] = daily["total_dv01"].apply(sdr.format_dv01)

display(daily.round(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       1 def top_tenors(group, n=3):
#       2     return ", ".join(
#       3         group.groupby("tenor_label")["dv01"]
#       4         .sum()
#       5         .nlargest(n)
#       6         .index.tolist()
#       7     )
# ----> 9 daily = df.groupby("execution_date").agg(
#      10     trade_count=("dv01", "size"),
#      11     total_dv01=("dv01", "sum"),
#      12     avg_dv01=("dv01", "mean"),
#      13     pct_packages=("package_type", lambda x: (x.fillna("OUTRIGHT") != "OUTRIGHT").mean() * 100),
#      14     pct_spreadovers=("is_spreadover", lambda x: x.fillna(False).mean() * 100),
#      15     unique_tenors=("tenor_label", "nunique"),
#      16 )
#      17 daily["top_tenors"] = df.groupby("execution_date").apply(top_tenors)
#      18 daily["total_dv01_fmt"] = daily["total_dv01"].apply(sdr.format_dv01)
#
# NameError: name 'df' is not defined
