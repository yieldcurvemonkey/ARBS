# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import nest_asyncio
nest_asyncio.apply()

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "vscode"            

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib.dates as mdates
plt.style.use('ggplot')
params = {'legend.fontsize': 'x-large',
        'figure.figsize': (12, 8),
        'axes.labelsize': 'x-large',
        'axes.titlesize':'x-large',
        'xtick.labelsize':'x-large',
        'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

import pandas as pd
import numpy as np

import datetime
import pytz
NY_tz = pytz.timezone("America/New_York") 
CHI_tz = pytz.timezone("America/Chicago") 
UTC_tz = pytz.timezone("UTC")

# %%
from MDP.FixedRateBonds.PUBLICDOTCOM.PublicDotcomDataFetcher import PublicDotcomDataFetcher 
from MDP.FixedRateBonds.FEDINVEST.FedInvestFetcher import FedInvestDataFetcher
from MDP.FixedRateBonds.WSJ.WSJFetcher import WSJFetcher
from MDP.FixedRateBonds.reference_data_cache.ust_reference_data import update_reference_data

from MDP.FixedRateBonds.FixedRateBondsMDP import FixedRateBondsMDP

import QuantLib as ql
from BT.misc import ql_cal_date_range

# %%
# update_reference_data(source="fiscaldata")

# %%
bdays = ql_cal_date_range(ql.UnitedStates(ql.UnitedStates.GovernmentBond), datetime.date(2009, 1, 1), datetime.date(2025, 10, 1))
# bdays

# %%
FedInvestDataFetcher().runner(dates=[datetime.datetime(2025, 7, 3)], show_tqdm=True)
# Out:
# {datetime.datetime(2025, 7, 3, 0, 0):          cusip               type  coupon  offer_price   bid_price   eod_price
#  0    912796JN0  MARKET BASED BILL   0.000     0.000000   99.999500  100.000000
#  1    912796HJ1  MARKET BASED BILL   0.000    99.995111   99.994889   99.995333
#  2    912796JQ3  MARKET BASED BILL   0.000    99.990208   99.990000   99.990278
#  3    912796JR1  MARKET BASED BILL   0.000    99.984417   99.984111   99.984833
#  4    912796JS9  MARKET BASED BILL   0.000    99.979056   99.978250   99.979778
#  ..         ...                ...     ...          ...         ...         ...
#  381  912828XN5   MARKET BASED FRN   0.394   100.038815  100.034680  100.036750
#  382  912828M23   MARKET BASED FRN   0.486   100.122100  100.116690  100.124800
#  383  912828N97   MARKET BASED FRN   0.592   100.244545  100.242870  100.232860
#  384  912828Q86   MARKET BASED FRN   0.509   100.095550  100.093180  100.098710
#  385  912828S84   MARKET BASED FRN   0.492   100.011880  100.002720   99.979810
#
#  [386 rows x 6 columns]}

# %%
WSJFetcher().fetch_live_ust_quotes(cusips=["912810UA4", "912810UM8"])
# Out:
# {'912810UA4': {'price': 98.282, 'ytm': 4.698},
#  '912810UM8': {'price': 101.002, 'ytm': 4.687}}

# %%
WSJFetcher().wsj_timeseries_api(wsj_ticker_keys=["BOND/US/XTUP/912810UA42"], append_most_recent_last=True)
# Out:
# {'BOND/US/XTUP/912810UA42':                        Date  BOND/US/XTUP/912810UA42
#  0 2025-10-03 12:39:12+00:00                    4.698}

# %%
frb_mdp = FixedRateBondsMDP(source="USTS_PUBLICDOTCOM_WSJ_LIVE-QL")

# %%
ql_frb_pricer = frb_mdp._get_pricer(cusip="912810UM8", timestamp=datetime.date(2025, 9, 25), kwargs={"force_refresh": False})

# %%
ql_frb_pricer.bpv()
# Out:
# np.float64(1587.7045372798898)
